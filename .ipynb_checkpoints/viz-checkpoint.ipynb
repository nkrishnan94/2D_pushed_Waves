# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
f = glob.glob('prof*')
nDemes=200
f
# Out:
# ['prof_K500000_M0.002_B0_G0.5_U200000_I2_2021-04-19-18-11-41.txt']

# %%
farr=np.loadtxt(f[0])

# %%
plt.imshow(farr[:,2:].reshape((nDemes,nDemes,2))[:,:,0]/(farr[:,2:].reshape((nDemes,nDemes,2))[:,:,0]+farr[:,2:].reshape((nDemes,nDemes,2))[:,:,1]))
# Out:
# <ipython-input-233-ad0a9eb92ec3>:1: RuntimeWarning: invalid value encountered in true_divide
#   plt.imshow(farr[:,2:].reshape((nDemes,nDemes,2))[:,:,0]/(farr[:,2:].reshape((nDemes,nDemes,2))[:,:,0]+farr[:,2:].reshape((nDemes,nDemes,2))[:,:,1]))

# %%
fs = glob.glob('final*')

# %%
plt.imshow(np.loadtxt(fs[0])[:,2].reshape((nDemes,nDemes)))

# %%
grid = np.loadtxt(fs[0])[:,2].reshape((nDemes,nDemes))

# %%
plt.imshow(grid)

# %%
def floodFill(arr,x,y):
    if arr[x][y]>-1:
        if arr[x-1][y]==0:
            arr[x]
            floodFill(arr,x-1,y)
            
        if arr[x+1][y]==0:
            floodFill(arr,x+1,y)
        if arr[x][y+1]==0:
            floodFill(arr,x,y+1)
        if arr[x][y-1]==0:
            floodFill(arr,x,y-1)
            
            
    return arr

# %%
import sys 
sys.setrecursionlimit(10000)
plt.imshow(floodFill(grid,9,86))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-38-815bffd59ac0> in <module>
#       1 import sys
#       2 sys.setrecursionlimit(10000)
# ----> 3 plt.imshow(floodFill(grid,9,86))
#
# <ipython-input-37-b692728bd7f0> in floodFill(arr, x, y)
#       5
#       6         if arr[x+1][y]==0:
# ----> 7             floodFill(arr,x+1,y)
#       8         if arr[x][y+1]==0:
#       9             floodFill(arr,x,y+1)
#
# <ipython-input-37-b692728bd7f0> in floodFill(arr, x, y)
#       2     if arr[x][y]>-1:
#       3         if arr[x-1][y]==0:
# ----> 4             floodFill(arr,x-1,y)
#       5
#       6         if arr[x+1][y]==0:
#
# ... last 2 frames repeated, from the frame below ...
#
# <ipython-input-37-b692728bd7f0> in floodFill(arr, x, y)
#       5
#       6         if arr[x+1][y]==0:
# ----> 7             floodFill(arr,x+1,y)
#       8         if arr[x][y+1]==0:
# ...

# %%
grid[9,]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f02e76c1a301> in <module>
# ----> 1 grid[9,]
#
# NameError: name 'grid' is not defined

# %%
np.argwhere(grid == 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-050feb6c6d38> in <module>
# ----> 1 np.argwhere(grid == 0)
#
# NameError: name 'grid' is not defined
