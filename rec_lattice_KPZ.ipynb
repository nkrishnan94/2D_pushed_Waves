# %%
import pandas as pd
import numpy as np
import glob
import os
import seaborn as sns
import matplotlib.pylab as pl
from matplotlib import colors, cm
import matplotlib
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib import cm, colors

import matplotlib.pyplot as plt

from scipy.optimize import curve_fit

# %%
path ="rec_lattice_bounds/KPZ/sim_data_KPZ/"
rough_64_files = glob.glob(path+"rough_64_*.txt")
rough_128_files = glob.glob(path+"rough_128_*.txt")
rough_256_files = glob.glob(path+"rough_256_*.txt")
rough_512_files = glob.glob(path+"rough_512_*.txt")
rough_1024_files = glob.glob(path+"rough_1024_*.txt")

rough_2048_files = glob.glob(path+"rough_2048_*.txt")
rough_4096_files = glob.glob(path+"rough_4096_*.txt")
rough_8192_files = glob.glob(path+"rough_8192_*.txt")

het_files = glob.glob(path+"het*.txt")

# %%
K_var = [1000,5000,10000,50000, 500000,1000000]
K_str = ["K"+str(K)+"_" for K in K_var]


B_var = [0, 2.5, 3.5, 6, 10 ]
B_str = ["B"+str(B)+"_" for B in B_var]

# %%
n_files =10
rough_data_big=np.zeros((5,6,n_files,8,300,3)) 
het_data_big=np.zeros((5,6,n_files,300,2)) 
for Kn, Ki,K in zip(range(len(K_var)),K_var,K_str):
    for Bn,Bi,B in zip(range(len(B_var)),B_var,B_str):
        #print('hi')


        rough_sub_files_64=[]c
        rough_sub_files_128=[]
        rough_sub_files_256=[]
        rough_sub_files_512=[]
        rough_sub_files_1024=[]
        rough_sub_files_2048=[]
        rough_sub_files_4096=[]
        rough_sub_files_8192=[]

        

        het_sub_files = []
        #for fr10,fr20,fr30,fr40,fr50,fr60,fr70 in zip(rough_10_files,rough_20_files,rough_30_files,rough_40_files,rough_50_files,rough_50_files,rough_50_files):
        #    print(fr10)
        #    if K in fr10 and B in fr10:
        #        rough_sub_files_10.append(fr10)

        for fr64,fr128,fr256,fr512,fr1024,fr2048,fr4096,fr8192,fh in zip(rough_64_files,rough_128_files,rough_256_files,rough_512_files,rough_1024_files,rough_2048_files,rough_4096_files,rough_8192_files,het_files):
            #print(fr10)

            if K in fr64 and B in fr64:
                rough_sub_files_64.append(fr64)
            if K in fr128 and B in fr128:
                rough_sub_files_128.append(fr128)
            if K in fr256 and B in fr256:
                 rough_sub_files_256.append(fr256)
            if K in fr512 and B in fr512:
                 rough_sub_files_512.append(fr512)
            if K in fr1024 and B in fr1024:
                rough_sub_files_1024.append(fr1024)
            if K in fr2048 and B in fr2048:
                rough_sub_files_2048.append(fr2048)
            if K in fr4096 and B in fr4096:
                rough_sub_files_4096.append(fr4096)
            if K in fr8192 and B in fr8192:
                rough_sub_files_8192.append(fr8192)
       

            if K in fh and B in fh:
                het_sub_files.append(fh)
#         for i, fr10,fr20,fr30,fr40,fr50,fr60,fr70,fr80,fr90,fr100,fr110,fr120,fr130,fr140,fr150,fr160,fr170,fr180 in zip(range(len(rough_sub_files_10)),rough_sub_files_10,rough_sub_files_20,rough_sub_files_30,rough_sub_files_40,
#                                                              rough_sub_files_50,rough_sub_files_60,rough_sub_files_70,rough_sub_files_80,
#                                                                                     rough_sub_files_90,rough_sub_files_100,rough_sub_files_110,
#                                                                                                        rough_sub_files_120,rough_sub_files_130,rough_sub_files_140,rough_sub_files_150,rough_sub_files_160,rough_sub_files_170,rough_sub_files_180):
#             rough_data[Bn,Kn,i,0]= np.loadtxt(fr10,delimiter =  ', ')
#             rough_data[Bn,Kn,i,1]= np.loadtxt(fr20,delimiter =  ', ')
#             rough_data[Bn,Kn,i,2]= np.loadtxt(fr30,delimiter =  ', ')
#             rough_data[Bn,Kn,i,3]= np.loadtxt(fr40,delimiter =  ', ')
#             rough_data[Bn,Kn,i,4]= np.loadtxt(fr50,delimiter =  ', ')
#             rough_data[Bn,Kn,i,5]= np.loadtxt(fr60,delimiter =  ', ')
#             rough_data[Bn,Kn,i,6]= np.loadtxt(fr70,delimiter =  ', ')
#             rough_data[Bn,Kn,i,7]= np.loadtxt(fr80,delimiter =  ', ')
#             rough_data[Bn,Kn,i,8]= np.loadtxt(fr90,delimiter =  ', ')
#             rough_data[Bn,Kn,i,9]= np.loadtxt(fr100,delimiter =  ', ')
#             rough_data[Bn,Kn,i,10]= np.loadtxt(fr110,delimiter =  ', ')
#             rough_data[Bn,Kn,i,11]= np.loadtxt(fr120,delimiter =  ', ')
#             rough_data[Bn,Kn,i,12]= np.loadtxt(fr130,delimiter =  ', ')
#             rough_data[Bn,Kn,i,13]= np.loadtxt(fr140,delimiter =  ', ')
#             rough_data[Bn,Kn,i,14]= np.loadtxt(fr150,delimiter =  ', ')
#             rough_data[Bn,Kn,i,15]= np.loadtxt(fr160,delimiter =  ', ')
#             rough_data[Bn,Kn,i,16]= np.loadtxt(fr170,delimiter =  ', ')
#             rough_data[Bn,Kn,i,17]= np.loadtxt(fr180,delimiter =  ', ')

            
                
        
        for i,fr64,fr128,fr256,fr512,fr1024,fr2048,fr4096,fr8192,fh in zip(range(n_files),rough_sub_files_64,rough_sub_files_128,rough_sub_files_256,rough_sub_files_512,rough_sub_files_1024,rough_sub_files_2048,rough_sub_files_4096,rough_sub_files_8192,het_sub_files):
         
            #arr = np.loadtxt(fr,delimiter =  ', ',skiprows=1)
            #rough_data[Bn,Kn,i,:,0]= np.concatenate((np.repeat(np.array([[0,10,20,30,40,50]]),1000,axis=0),
            #                             np.array([arr[:,-1]-8,arr[:,-1]-6,arr[:,-1]-4,arr[:,-1]-2,arr[:,-1]]).T),axis=1)
            #rough_data[Bn,Kn, i,:,1] = arr[:,1:-1]
            #print(i)
 

            rough_data_big[Bn,Kn,i,0]= np.loadtxt(fr64,delimiter =  ', ')
            rough_data_big[Bn,Kn,i,1]= np.loadtxt(fr128,delimiter =  ', ')
            rough_data_big[Bn,Kn,i,2]= np.loadtxt(fr256,delimiter =  ', ')
            rough_data_big[Bn,Kn,i,3]= np.loadtxt(fr512,delimiter =  ', ')
            rough_data_big[Bn,Kn,i,4]= np.loadtxt(fr1024,delimiter =  ', ')
            rough_data_big[Bn,Kn,i,5]= np.loadtxt(fr2048,delimiter =  ', ')
            rough_data_big[Bn,Kn,i,6]= np.loadtxt(fr4096,delimiter =  ', ')
            rough_data_big[Bn,Kn,i,7]= np.loadtxt(fr8192,delimiter =  ', ')


            het_data_big[Bn,Kn,i]= np.loadtxt(fh,delimiter =  ', ')

# %%
L_space = 2**np.arange(6,14)

# %%
K
# Out:
# 0

# %%
fig,axs=plt.subplots(3,4,figsize=(12,6),sharex=True,sharey=True)

for Bi,B in  enumerate([0,1,-1]):
    for Ki,K in  enumerate([1,3,-2,-1]):
        ax= axs[Bi,Ki]

        colors = pl.cm.viridis(np.linspace(0,1,8))
        norm = matplotlib.colors.Normalize(vmin=0, vmax=8192)
        cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
        cmap.set_array([])

        for i in range(1,8):
            if K !=-1 and B!=-1:
                ax.scatter(np.mean(rough_data_big[B,K,:,i,:,0],axis=0),
                        ((np.mean(rough_data_big[B,K,:,i,:,2],axis=0)/L_space[i] - np.mean(rough_data_big[B,K,:,i,0,2])/L_space[i]))**.5,
                          s=6,color=colors[i] )
            else:
                ax.scatter(np.mean(rough_data_big[B,K,:,i,:,0],axis=0),
            ((np.mean(rough_data_big[B,K,:,i,:,2],axis=0)/L_space[i] - np.mean(rough_data_big[B,K,:,i,0,2])/L_space[i]))**.5,
              s=6, label= "L = "+str( L_space[i]),color=colors[i])




        def power_law(x, a, b):
             return a*(np.power((x), b))


        xdata= np.mean(rough_data_big[B,K,:,-1,0:60,0],axis=0)
        ydata = (np.mean(rough_data_big[B,K,:,-1,0:60,2],axis=0)/L_space[-1] - np.mean(rough_data_big[B,K,:,-1,0,2])/L_space[-1])**.5
        pars, cov = curve_fit(f=power_law, xdata=xdata, ydata=ydata, p0=[0, 0], bounds=(-np.inf, np.inf))
        #if K==4:
        #    print(y_data)

        #ax.plot(np.mean(rough_data_big[B,K,:,-3,10:,0],axis=0),power_law(np.mean(rough_data_big[B,K,:,-3,10:,0],axis=0),*pars),
        #         linestyle= "--", color = 'k' , label = '$L \propto t^{%f}$' % (pars[1]))
        if K==-1 and B ==-1:
            ax.plot(np.mean(rough_data_big[B,K,:,-1,0:,0],axis=0),(ydata[1]/xdata[1]**(1/3))*(np.mean(rough_data_big[B,K,:,-1,0:,0],axis=0))**(1/3) ,
                    linestyle= '--',c='k',label = '$L \propto t^{1/3}$' )
            ax.legend(fontsize=16, bbox_to_anchor=(1,2))
        else:
            ax.plot(np.mean(rough_data_big[B,K,:,-1,0:,0],axis=0),(ydata[1]/xdata[1]**(1/3))*(np.mean(rough_data_big[B,K,:,-1,0:,0],axis=0))**(1/3) ,
                    linestyle= '--',c='k')
            
        #print(ydata[1])

        #ax.set_xlabel('Generations',fontsize=16)
        #ax.set_ylabel('$\omega (x,t)$',fontsize=16)


        for axis in ['bottom','left']:
            ax.spines[axis].set_linewidth(3)
            ax.spines['right'].set_visible(False)
            ax.spines['top'].set_visible(False)

            ax.xaxis.set_tick_params(labelsize=16)
            ax.yaxis.set_tick_params(labelsize=16)


        ax.set_xscale('log')
        ax.set_yscale('log')
        ax.set_xlim([.5,300])
        
        ax.set_yticks([.5,1,3])
        ax.set_yticklabels([.5,1,3])
        

      
    
for i in range(4):
    ax.set_ylim([.2,5])
    axs[0,i].text(10,10,'K = '+str( np.array(K_var)[[1,3,-2,-1]][i]),fontsize=14)

for i in range(4):

    axs[2,i].set_xlabel('Generations',fontsize=20)
    
for i in range(3):

    axs[i,0].set_ylabel(r'$\omega(x,t)$',fontsize=20)
    axs[i,0].text(.01,3,'B = '+str( np.array(B_var)[[0,1,-1]][i]),fontsize=14)
# Out:
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in sqrt

# %%
fig,axs=plt.subplots(5,6,figsize=(12,6),sharex=True,sharey=True)

for B in  range(len(B_var)):
    for K in  range(len(K_var)):
        ax= axs[B,K]

        colors = pl.cm.viridis(np.linspace(0,1,8))
        norm = matplotlib.colors.Normalize(vmin=0, vmax=8192)
        cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
        cmap.set_array([])

        for i in range(1,8):
            if K !=-1 and B!=-1:
                ax.scatter(np.mean(rough_data_big[B,K,:,i,:,0],axis=0),
                        ((np.mean(rough_data_big[B,K,:,i,:,2],axis=0)/L_space[i] - np.mean(rough_data_big[B,K,:,i,0,2])/L_space[i]))**.5,
                          s=6,color=colors[i] )
            else:
                ax.scatter(np.mean(rough_data_big[B,K,:,i,:,0],axis=0),
            ((np.mean(rough_data_big[B,K,:,i,:,2],axis=0)/L_space[i] - np.mean(rough_data_big[B,K,:,i,0,2])/L_space[i]))**.5,
              s=6, label= "L = "+str( L_space[i]),color=colors[i])




        def power_law(x, a, b):
             return a*(np.power((x), b))


        xdata= np.mean(rough_data_big[B,K,:,-1,0:60,0],axis=0)
        ydata = (np.mean(rough_data_big[B,K,:,-1,0:60,2],axis=0)/L_space[-1] - np.mean(rough_data_big[B,K,:,-1,0,2])/L_space[-1])**.5
        pars, cov = curve_fit(f=power_law, xdata=xdata, ydata=ydata, p0=[0, 0], bounds=(-np.inf, np.inf))
        #if K==4:
        #    print(y_data)

        #ax.plot(np.mean(rough_data_big[B,K,:,-3,10:,0],axis=0),power_law(np.mean(rough_data_big[B,K,:,-3,10:,0],axis=0),*pars),
        #         linestyle= "--", color = 'k' , label = '$L \propto t^{%f}$' % (pars[1]))
        if K==-1 and B ==-1:
            ax.plot(np.mean(rough_data_big[B,K,:,-1,0:,0],axis=0),(ydata[1]/xdata[1]**(1/3))*(np.mean(rough_data_big[B,K,:,-1,0:,0],axis=0))**(1/3) ,
                    linestyle= '--',c='k',label = '$L \propto t^{1/3}$' )
            ax.legend(fontsize=16, bbox_to_anchor=(1,2))
        else:
            ax.plot(np.mean(rough_data_big[B,K,:,-1,0:,0],axis=0),(ydata[1]/xdata[1]**(1/3))*(np.mean(rough_data_big[B,K,:,-1,0:,0],axis=0))**(1/3) ,
                    linestyle= '--',c='k')
            
        #print(ydata[1])

        #ax.set_xlabel('Generations',fontsize=16)
        #ax.set_ylabel('$\omega (x,t)$',fontsize=16)


        for axis in ['bottom','left']:
            ax.spines[axis].set_linewidth(3)
            ax.spines['right'].set_visible(False)
            ax.spines['top'].set_visible(False)

            ax.xaxis.set_tick_params(labelsize=16)
            ax.yaxis.set_tick_params(labelsize=16)


        ax.set_xscale('log')
        ax.set_yscale('log')
        ax.set_xlim([.5,300])
        
        ax.set_yticks([.5,1,3])
        ax.set_yticklabels([.5,1,3])
        

      
    
for i in range(6):
    ax.set_ylim([.2,5])
    axs[0,i].text(10,10,'K = '+str( np.array(K_var)[i]),fontsize=14)

for i in range(6):

    axs[-1,i].set_xlabel('Generations',fontsize=16)
    
for i in range(5):

    axs[i,0].set_ylabel(r'$\omega(x,t)$',fontsize=16)
    axs[i,0].text(.001,3,'B = '+str( np.array(B_var)[i]),fontsize=12)
# Out:
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in sqrt
#   from ipykernel import kernelapp as app

# %%
fig,ax=plt.subplots()


colors = pl.cm.viridis(np.linspace(0,1,8))
norm = matplotlib.colors.Normalize(vmin=0, vmax=8192)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
B= 0
K=-1

for i in range(8):
    ax.scatter(np.mean(rough_data_big[B,K,:,i,:,0],axis=0),
            ((np.mean(rough_data_big[B,K,:,i,:,2],axis=0)/L_space[i] - np.mean(rough_data_big[B,K,:,i,0,2])/L_space[i]))**.5,
              s=4, label= "L = "+str( L_space[i]),color=colors[i])
    
    

def power_law(x, a, b):
     return a*(np.power((x), b))


xdata= np.mean(rough_data_big[B,K,:,-1,:50,0],axis=0)
ydata = (np.mean(rough_data_big[B,K,:,-1,:50,2],axis=0)/L_space[-1] - np.mean(rough_data_big[B,K,:,-1,0,2],axis=0)/L_space[-1])**.5
pars, cov = curve_fit(f=power_law, xdata=xdata, ydata=ydata, p0=[0, 0], bounds=(-np.inf, np.inf))


#ax.plot(np.mean(rough_data_big[B,K,:,-2,6:,0],axis=0),power_law(np.mean(rough_data_big[B,K,:,-1,6:,0],axis=0),*pars),
#         linestyle= "--", color = 'k' , label = '$L \propto t^{%f}$' % (pars[1]))

ax.plot(np.mean(rough_data_big[B,K,:,-1,:,0],axis=0),(ydata[40]/xdata[40]**(1/3))*(np.mean(rough_data_big[B,K,:,-1,:,0],axis=0))**(1/3) ,linestyle= '--',c='k',label = '$L \propto t^{1/3}$')
ax.legend()

ax.set_xlabel('Generations',fontsize=16)
ax.set_ylabel('$\omega (x,t)$',fontsize=16)


for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(3)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    ax.xaxis.set_tick_params(labelsize=16)
    ax.yaxis.set_tick_params(labelsize=16)

    
#ax.set_xscale('log')
#ax.set_yscale('log')
ax.set_xlim([.8,300])
ax.set_ylim([.3,5])
ax.set_title(r'$K=10^6 $ , B = 0')
ax.set_xscale('log')
ax.set_yscale('log')
pars[1]
# Out:
# 0.3070082973405741

# %%
all_alpha=np.zeros((len(B_var),len(K_var)))
for B in range(len(B_var)):
    for K in range(len(K_var[:])):
        xdata= np.mean(rough_data_big[B,K,:,-1,10:50,0],axis=0)
        ydata = (np.mean(rough_data_big[B,K,:,-1,10:50,2],axis=0)/L_space[-1] - np.mean(rough_data_big[B,K,:,-1,0,2],axis=0)/L_space[-1])**.5
        pars, cov = curve_fit(f=power_law, xdata=xdata, ydata=ydata, p0=[0, 0], bounds=(-np.inf, np.inf))

        all_alpha[B,K] = pars[1]

# %%
fig,ax=plt.subplots()
colors = pl.cm.viridis(np.linspace(0,1,5))
norm = matplotlib.colors.Normalize(vmin=0, vmax=8192)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
for i in range(5):
    ax.plot(all_alpha[i].T,c=colors[i],label='B = ' +str(B_var[i]),lw=3)
    ax.scatter(range(6),all_alpha[i].T,c=colors[i])
    
    
for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(3)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    ax.xaxis.set_tick_params(labelsize=16)
    ax.yaxis.set_tick_params(labelsize=16)
    
ax.set_xticks(range(6))
ax.set_xticklabels([r'$10^3$',r'$5 \times 10^3$',r'$10^4$', r'$5 \times 10^4$',r'$5 \times 10^5$',r'$10^6$'])
ax.set_xlabel('K',fontsize=16)
ax.set_ylabel(r'$\alpha$',fontsize=16)
ax.legend(bbox_to_anchor=(1,1),fontsize=14)

# %%
rough_64_files
# Out:
# ['rec_lattice_bounds/KPZ/sim_data_KPZ/rough_64_K1000000_M0.25_B0_G0.01_2020-08-24-19-34-15.txt',
#  'rec_lattice_bounds/KPZ/sim_data_KPZ/rough_64_K1000000_M0.25_B0_G0.01_2020-08-24-16-56-15.txt',
#  'rec_lattice_bounds/KPZ/sim_data_KPZ/rough_64_K1000000_M0.25_B2.5_G0.01_2020-08-24-20-15-10.txt',
#  'rec_lattice_bounds/KPZ/sim_data_KPZ/rough_64_K1000000_M0.25_B3.5_G0.01_2020-08-24-15-07-32.txt',
#  'rec_lattice_bounds/KPZ/sim_data_KPZ/rough_64_K1000000_M0.25_B2.5_G0.01_2020-08-25-07-21-29.txt',
#  'rec_lattice_bounds/KPZ/sim_data_KPZ/rough_64_K1000000_M0.25_B3.5_G0.01_2020-08-25-16-44-59.txt',
#  'rec_lattice_bounds/KPZ/sim_data_KPZ/rough_64_K1000000_M0.25_B10_G0.01_2020-08-25-08-50-24.txt',
#  'rec_lattice_bounds/KPZ/sim_data_KPZ/rough_64_K1000000_M0.25_B0_G0.01_2020-08-24-22-10-21.txt',
#  'rec_lattice_bounds/KPZ/sim_data_KPZ/rough_64_K1000000_M0.25_B0_G0.01_2020-08-25-06-42-08.txt',
# ...

# %%
path ="rec_lattice_bounds/KPZ/sim_data_KPZ/"

rough_64_files = glob.glob(path+"rough_64_*.txt")
rough_128_files = glob.glob(path+"rough_128_*.txt")
rough_256_files = glob.glob(path+"rough_256_*.txt")
rough_512_files = glob.glob(path+"rough_512_*.txt")

het_files = glob.glob(path+"het*.txt")

# %%
K_var = [1000000]
K_str = ["K"+str(K)+"_" for K in K_var]


B_var = [0,2.5,3.5,6,10]
B_str = ["B"+str(B)+"_" for B in B_var]

# %%
n_files =30

rough_data_long_big=np.zeros((5,1,n_files,4,300,3)) 
het_data_long_big=np.zeros((5,1,n_files,300,2)) 
for Kn, Ki,K in zip(range(len(K_var)),K_var,K_str):
    for Bn,Bi,B in zip(range(len(B_var)),B_var,B_str):
        #print('hi')


        rough_sub_files_64=[]
        rough_sub_files_128=[]
        rough_sub_files_256=[]
        rough_sub_files_512=[]

        

        het_sub_files = []
        #for fr10,fr20,fr30,fr40,fr50,fr60,fr70 in zip(rough_10_files,rough_20_files,rough_30_files,rough_40_files,rough_50_files,rough_50_files,rough_50_files):
        #    print(fr10)
        #    if K in fr10 and B in fr10:
        #        rough_sub_files_10.append(fr10)

        for fr64,fr128,fr256,fr512,fh in zip(rough_64_files,rough_128_files,rough_256_files,rough_512_files,het_files):
            #print(fr10)


            if K in fr64 and B in fr64:
                rough_sub_files_64.append(fr64)
            if K in fr128 and B in fr128:
                rough_sub_files_128.append(fr128)
            if K in fr256 and B in fr256:
                rough_sub_files_256.append(fr256)
            if K in fr512 and B in fr512:
                rough_sub_files_512.append(fr512)
       

            if K in fh and B in fh:
                het_sub_files.append(fh)
#         for i, fr10,fr20,fr30,fr40,fr50,fr60,fr70,fr80,fr90,fr100,fr110,fr120,fr130,fr140,fr150,fr160,fr170,fr180 in zip(range(len(rough_sub_files_10)),rough_sub_files_10,rough_sub_files_20,rough_sub_files_30,rough_sub_files_40,
#                                                              rough_sub_files_50,rough_sub_files_60,rough_sub_files_70,rough_sub_files_80,
#                                                                                     rough_sub_files_90,rough_sub_files_100,rough_sub_files_110,
#                                                                                                        rough_sub_files_120,rough_sub_files_130,rough_sub_files_140,rough_sub_files_150,rough_sub_files_160,rough_sub_files_170,rough_sub_files_180):
#             rough_data[Bn,Kn,i,0]= np.loadtxt(fr10,delimiter =  ', ')
#             rough_data[Bn,Kn,i,1]= np.loadtxt(fr20,delimiter =  ', ')
#             rough_data[Bn,Kn,i,2]= np.loadtxt(fr30,delimiter =  ', ')
#             rough_data[Bn,Kn,i,3]= np.loadtxt(fr40,delimiter =  ', ')
#             rough_data[Bn,Kn,i,4]= np.loadtxt(fr50,delimiter =  ', ')
#             rough_data[Bn,Kn,i,5]= np.loadtxt(fr60,delimiter =  ', ')
#             rough_data[Bn,Kn,i,6]= np.loadtxt(fr70,delimiter =  ', ')
#             rough_data[Bn,Kn,i,7]= np.loadtxt(fr80,delimiter =  ', ')
#             rough_data[Bn,Kn,i,8]= np.loadtxt(fr90,delimiter =  ', ')
#             rough_data[Bn,Kn,i,9]= np.loadtxt(fr100,delimiter =  ', ')
#             rough_data[Bn,Kn,i,10]= np.loadtxt(fr110,delimiter =  ', ')
#             rough_data[Bn,Kn,i,11]= np.loadtxt(fr120,delimiter =  ', ')
#             rough_data[Bn,Kn,i,12]= np.loadtxt(fr130,delimiter =  ', ')
#             rough_data[Bn,Kn,i,13]= np.loadtxt(fr140,delimiter =  ', ')
#             rough_data[Bn,Kn,i,14]= np.loadtxt(fr150,delimiter =  ', ')
#             rough_data[Bn,Kn,i,15]= np.loadtxt(fr160,delimiter =  ', ')
#             rough_data[Bn,Kn,i,16]= np.loadtxt(fr170,delimiter =  ', ')
#             rough_data[Bn,Kn,i,17]= np.loadtxt(fr180,delimiter =  ', ')

            
                
        
        for i,fr64,fr128,fr256,fr512,fh in zip(range(n_files),rough_sub_files_64,rough_sub_files_128,rough_sub_files_256,rough_sub_files_512,het_sub_files):
         
            #arr = np.loadtxt(fr,delimiter =  ', ',skiprows=1)
            #rough_data[Bn,Kn,i,:,0]= np.concatenate((np.repeat(np.array([[0,10,20,30,40,50]]),1000,axis=0),
            #                             np.array([arr[:,-1]-8,arr[:,-1]-6,arr[:,-1]-4,arr[:,-1]-2,arr[:,-1]]).T),axis=1)
            #rough_data[Bn,Kn, i,:,1] = arr[:,1:-1]
            #print(i)
 

            rough_data_long_big[Bn,Kn,i,0]= np.loadtxt(fr64,delimiter =  ', ')
            rough_data_long_big[Bn,Kn,i,1]= np.loadtxt(fr128,delimiter =  ', ')
            rough_data_long_big[Bn,Kn,i,2]= np.loadtxt(fr256,delimiter =  ', ')
            rough_data_long_big[Bn,Kn,i,3]= np.loadtxt(fr512,delimiter =  ', ')



            het_data_long_big[Bn,Kn,i]= np.loadtxt(fh,delimiter =  ', ')

# %%
files
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-ec6206aa1935> in <module>()
# ----> 1 files
#
# NameError: name 'files' is not defined

# %%
rough_data_long_big[2,0,:,3,0,2]
# Out:
# array([1388., 1570., 1406., 1444., 1487., 1412., 1480., 1241., 1460.,
#        1424., 1517., 1549., 1319., 1480., 1531., 1454., 1435., 1390.,
#        1461., 1676., 1488., 1427., 1579., 1407., 1488., 1405., 1416.,
#        1533., 1404., 1302.])

# %%
L_space = np.array([64,128,256,512])

# %%
plt.plot(L_space, (np.mean(np.mean(rough_data_long_big[0,0,:,:,-100:,2],axis=2),axis=0)/L_space))

# %%
plt.plot(np.mean(rough_data_long_big[1,0,:,1,:,0],axis=0),np.mean(rough_data_long_big[0,0,:,0,:,2],axis=0))

# %%
L_space = np.array([4,8,16,32,64,128])

# %%
rough_data_long_big[B,K,:,L,-1,2]
# Out:
# array([269., 266., 303., 306., 251., 298., 347., 254., 181., 288., 308.,
#        632., 201., 197., 312., 291., 429., 232., 302., 187., 224., 232.,
#        180., 268., 183., 237., 488., 334., 287., 158., 270., 287., 342.,
#        360., 186., 274., 251., 358., 306., 143., 154., 359., 239., 159.,
#        339., 346., 323., 226., 224., 366., 380., 237., 368., 352., 246.,
#        313., 131., 190., 253., 185.])

# %%
B_var
# Out:
# [0, 2.5, 3.5, 6, 10]

# %%
fig,axs=plt.subplots(1,5,sharey=True,figsize=(12,3))
B=0
K=0
L=-2
for B in range(len(B_var)):
    ax=axs[B]
    w_e = (np.mean(rough_data_long_big[B,K,:,L,:,2],axis=0)/ L_space[L]  )**.5
    ax.plot(np.mean(rough_data_long_big[B,K,:,L,:,0],axis=0),w_e,lw=3)

    for axis in ['bottom','left']:
        ax.spines[axis].set_linewidth(3)
        ax.spines['right'].set_visible(False)
        ax.spines['top'].set_visible(False)

        ax.xaxis.set_tick_params(labelsize=16)
        ax.yaxis.set_tick_params(labelsize=16)


    #ax.set_xticks(range(5))
    #ax.set_xticklabels([r'$10^4$', r'$5 \times 10^4$',r'$5 \times 10^5$',r'$10^6$',r'$10^8$' ])
    ax.set_xlabel('Time',fontsize=16)
    #ax.set_ylabel('$\omega$',fontsize=16)
    #ax.set_xscale('log')
    ax.set_title('B = ' + str(B_var[B]))
    #ax.set_ylabel('$\omega_{max} / \omega_{sat} $',fontsize=16)
    
#ax[0].set_ylabel('$\omega$',fontsize=16)

# %%
fig,axs=plt.subplots(1,5,sharey=True,figsize=(12,3))
B=0
K=-1
L=-1
for B in range(len(B_var)):
    ax=axs[B]
    w_e = (np.mean(rough_data_long_big[B,K,:,L,:,2],axis=0)/ L_space[L]  )**.5
    ax.plot(np.mean(rough_data_long_big[B,K,:,L,:,0],axis=0)/np.mean(rough_data_long_big[B,K,:,L,:,0],axis=0)**(1/3),w_e / L_space[L]**.5 ,lw=3)

    for axis in ['bottom','left']:
        ax.spines[axis].set_linewidth(3)
        ax.spines['right'].set_visible(False)
        ax.spines['top'].set_visible(False)

        ax.xaxis.set_tick_params(labelsize=16)
        ax.yaxis.set_tick_params(labelsize=16)


    #ax.set_xticks(range(5))
    #ax.set_xticklabels([r'$10^4$', r'$5 \times 10^4$',r'$5 \times 10^5$',r'$10^6$',r'$10^8$' ])
    ax.set_xlabel('K',fontsize=16)
    ax.set_ylabel('$\omega$',fontsize=16)
    ax.set_xscale('log')
    ax.set_title('B = ' + str(B_var[B]))
    #ax.set_ylabel('$\omega_{max} / \omega_{sat} $',fontsize=16)
# Out:
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in true_divide

# %%
L_space
# Out:
# array([  4,   8,  12,  64, 128])

# %%
plt.plot(np.mean(rough_data_long_big[0,-1,:,:,250:400,2],axis=0).T)

# %%
fig, ax= plt.subplots()

for i in range(len(L_space[:])):
    ax.scatter(L_space[i], (np.mean(rough_data_long_big[0,-1,:,i,250:400,2])/L_space[i]   )**(.5),c='k')
    #print(L_space[i])
#plt.xscale('log')
#plt.yscale('log')


#plt.plot(L_space,L_space**.5)
def power_law(x, a,b):
    return a*(np.power((x), b))


xdata=L_space[:]
ydata =  (np.mean(np.mean(rough_data_long_big[0,-1,:,:,250:400,2],axis=2) ,axis=0)/L_space - np.mean(np.min(rough_data_long_big[0,-1,:,:,250:400,2],axis=2) ,axis=0)/L_space)  **(.5)
         


#pars, cov = curve_fit(f=power_law, xdata=xdata, ydata=ydata, p0=[0,0 ], bounds=(-np.inf, np.inf))

ax.plot(xdata[:],(ydata[2]/xdata[2]**.5)*xdata[:]**.5,lw=4,linestyle='--',label='$L^{1/2}$')


#ax.plot(xdata,ydata)

ax.legend(fontsize=12)
for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(3)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)


#plt.plot( xdata, power_law(xdata,*pars))

ax.set_xlabel('L',fontsize=16)
ax.set_ylabel('$\omega (x,t)$',fontsize=16)

#ax.set_xscale('log')
ax.set_yscale('log')
#ax.plot(xdata,ydata)
ax.xaxis.set_tick_params(labelsize=16)
ax.yaxis.set_tick_params(labelsize=16)

# %%
all_beta=np.zeros((len(B_var),len(K_var)))
for B in range(len(B_var)):
    for K in range(len(K_var[:])):
        xdata=L_space[:]
        ydata =  (np.mean((np.mean(rough_data_long_big[B,K,:,:,500:1000,2] ,axis=2)/L_space[:]),axis=0)  )**.5

        #xdata= np.mean(rough_data_big[B,K,:,-2,5:30,0],axis=0)
        #ydata = (np.mean(rough_data_big[B,K,:,-2,5:30,2],axis=0)/L_space[-2] - np.mean(rough_data_big[B,K,:,-2,0,2],axis=0)/L_space[-2])**.5
        pars, cov = curve_fit(f=power_law, xdata=xdata, ydata=ydata, p0=[0, 0], bounds=(-np.inf, np.inf))

        all_beta[B,K] = pars[1]

# %%
fig,ax=plt.subplots()
colors = pl.cm.viridis(np.linspace(0,1,5))
norm = matplotlib.colors.Normalize(vmin=0, vmax=8192)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
for i in range(5):
    ax.plot(all_beta[i].T,c=colors[i],label='B = ' +str(B_var[i]),lw=3,marker='o')

    
for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(3)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    ax.xaxis.set_tick_params(labelsize=16)
    ax.yaxis.set_tick_params(labelsize=16)
    
ax.set_xticks(range(4))
ax.set_xticklabels([r'$10^4$', r'$5 \times 10^4$',r'$5 \times 10^5$',r'$10^6$'])
ax.set_xlabel('K',fontsize=16)
ax.set_ylabel(r'$\beta$',fontsize=16)
ax.legend(bbox_to_anchor=(1,1),fontsize=14)

# %%
 (np.mean(np.mean(rough_data_long_big[0,-1,:,:,250:400,2],axis=2) ,axis=0)/L_space)**(.5)
# Out:
# array([1.28385271, 1.65016413, 2.11101608, 2.47787011, 2.86373821,
#        3.15006379])

# %%
colors = pl.cm.viridis(np.linspace(0,1,5))
norm = matplotlib.colors.Normalize(vmin=0, vmax=8192)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
w_rat = np.zeros((len(B_var),len(K_var),len(L_space)))
L_space = 2**np.array([6,7,8,9,10])
for B in range(len(B_var)):
    for K in range(len(K_var)):
        for L in range(len(L_space)):
            w_e = (np.mean(rough_data_long_big[B,K,:,L,:,2],axis=0)/ L_space[L] -np.min(rough_data_long_big[B,K,:,L,:,2],axis=0)/ L_space[L]   )**.5
            w_rat[B,K,L] = np.max(w_e)/np.mean(w_e[950:])
        #plt.scatter(K,np.max(w_e)/np.mean(w_e[900:]),c=colors[B])

# %%
w_rat
# Out:
# array([[[1.39925144, 1.3812852 , 1.31246289, 1.21404789, 1.17633846],
#         [1.39838193, 1.28377287, 1.17522026, 1.20306324, 1.07111594],
#         [1.58324328, 1.31893391, 1.36412592, 1.29024982, 1.3185419 ],
#         [1.40482271, 1.2100831 , 1.22420014, 1.16332954, 1.11019989]],
#
#        [[1.47190821, 1.2363452 , 1.18499296, 1.12620517, 1.0690289 ],
#         [1.78071617, 1.45688869, 1.27350233, 1.25207965, 1.22130619],
#         [1.7473993 , 1.51684227, 1.38062128, 1.28552181, 1.39280313],
#         [1.34839832, 1.24111256, 1.21877353, 1.33280699, 1.29965405]],
#
#        [[1.31177309, 1.35690842, 1.32013157, 1.28886038, 1.17568678],
#         [1.90596761, 1.74735586, 1.54088744, 1.43849036, 1.47742618],
#         [2.55847837, 2.41257786, 2.45584949, 2.32103546, 2.16119609],
#         [1.62705487, 1.55707587, 1.42222393, 1.42551952, 1.49058737]],
#
#        [[1.52762878, 1.34730488, 1.33940967, 1.27790765, 1.31454517],
# ...

# %%
fig,ax =plt.subplots()
colors = pl.cm.viridis(np.linspace(0,1,5))
norm = matplotlib.colors.Normalize(vmin=0, vmax=8192)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
for B in range(len(B_var)):
    ax.plot(w_rat[B,:,-2],color=colors[B],lw=3,marker='o',label='B = ' +str(B_var[B]))
    
for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(3)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    ax.xaxis.set_tick_params(labelsize=16)
    ax.yaxis.set_tick_params(labelsize=16)
    
ax.legend()
ax.set_xticks(range(5))
ax.set_xticklabels([r'$10^4$', r'$5 \times 10^4$',r'$5 \times 10^5$',r'$10^6$',r'$10^8$' ])
ax.set_xlabel('K',fontsize=16)
ax.set_ylabel('$\omega_{max} / \omega_{sat} $',fontsize=16)
# Out:
# Text(0,0.5,'$\\omega_{max} / \\omega_{sat} $')

# %%
np.mean(rough_data_long_big[B,:,:,-2,0,2],axis=1)/ L_space[-2]
# Out:
# array([0.28984375, 0.39541016, 0.22900391, 0.24423828, 0.48603516])

# %%
w_e = (np.mean(rough_data_long[0,0,:,-2,:,2],axis=0)/L_space[-2])**.5

w_f = (np.mean(rough_data_long[0,0,:,-2,:,1],axis=0)/L_space[-2] )**.5
normed_e = (w_e - w_e.mean(axis=0)) / w_e.std(axis=0)
normed_f = (w_f - w_f.mean(axis=0)) / w_f.std(axis=0)

# %%
tau_space = np.arange(-5,5)

# %%
tau_space
# Out:
# array([-5, -4, -3, -2, -1,  0,  1,  2,  3,  4])

# %%
lags = np.zeros((len(B_var),len(K_var)))
for B in range(len(B_var)):
    for K in range(len(K_var)):
        lim = 1000
        min_t=1
        tau_space = np.arange(min_t,lim)
        lag = np.zeros(lim-min_t)
        w_e = (np.mean(rough_data_long_big[B,K,:,-1,:,2],axis=0)/L_space[-1])**.5
        w_f = (np.mean(rough_data_long_big[B,K,:,-1,:,1],axis=0)/L_space[-1] )**.5
        normed_e = (w_e - w_e.mean(axis=0)) / w_e.std(axis=0)
        normed_f = (w_f - w_f.mean(axis=0)) / w_f.std(axis=0)
        dx = 10
        for i,tau in enumerate(tau_space):
            lag[i] = np.sum(normed_e[0:1000-tau]*normed_f[tau:1000])
        #print(B,K,np.argmax(lag)*dx)
     
        lags[B,K] = np.argmax(lag)*dx
            


        plt.plot(tau_space,lag)

            #plt.scatter(tau,np.sum(normed_e[0:600]*normed_f[0+tau:600+tau]))

# %%
find_peaks(lag)
# Out:
# (array([  3,   6,   9,  12,  15,  18,  21,  24,  27,  30,  33,  36,  40,
#          43,  46,  49,  52,  55,  58,  61,  64,  67,  70,  73,  76,  79,
#          83,  86,  89,  92,  95,  98, 101, 104, 107, 110, 113, 116, 119,
#         123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159,
#         162, 164, 166, 169, 172, 175, 178, 181, 184, 187, 190, 193, 196,
#         199, 202, 204, 209, 212, 215, 218, 221, 224, 227, 230, 233, 236,
#         239, 242, 245, 247, 250, 252, 255, 258, 261, 264, 267, 270, 273,
#         276, 279, 282, 285, 288, 290, 295, 298, 301, 304, 307, 310, 313,
#         316, 319, 322, 325, 328, 331, 333, 335, 338, 341, 344, 347, 350,
#         353, 356, 359, 362, 365, 368, 371, 374, 376, 378, 381, 384, 387,
#         390, 393, 396, 399, 402, 405, 408, 411, 414, 417, 419, 421, 424,
#         427, 430, 433, 436, 439, 442, 445, 448, 451, 454, 457, 459, 462,
#         467, 470, 473, 476, 479, 482, 485, 488, 491, 494, 497, 500, 502,
# ...

# %%
plt.plot(K_var,lags)
plt.xscale('log')
plt.yscale('log')

# %%
B=2
K=0
lim = 1000
min_t=0
tau_space = np.arange(min_t,lim)
lag = np.zeros(lim-min_t)
w_e = (np.mean(rough_data_long_big[B,K,:,-2,:,2],axis=0)/L_space[-2])**.5
w_f = (np.mean(rough_data_long_big[B,K,:,-2,:,1],axis=0)/L_space[-2] )**.5
normed_e = (w_e - w_e.mean(axis=0)) / w_e.std(axis=0)
normed_f = (w_f - w_f.mean(axis=0)) / w_f.std(axis=0)
dx = np.diff(np.mean(rough_data_long_big[B,K,0,:,0],axis=0))[0]
for i,tau in enumerate(tau_space):
    lag[i] = np.sum(normed_e[0:1000-tau]*normed_f[tau:1000])
    
    
plt.plot(tau_space,lag)

# %%
np.diff(np.mean(rough_data_long[B,K,:,:,:,0],axis=0)[0])[0]
# Out:
# 10.0

# %%
L_space
# Out:
# array([  64,  128,  256,  512, 1024])

# %% [markdown]
# #### plt.plot(normed_f)

# %%
#plt.plot(np.mean(rough_data_long[4,-1,:,:,:,2],axis=0).T)
#find_peaks(np.mean(rough_data_long[0,0,:,-2,:,1],axis=0).T[::-5])
plt.plot(np.mean(rough_data_long[0,0,:,:-1,:,1],axis=0).T)

# %%
path ="rec_lattice_bounds/KPZ/sim_data_KPZ_long/"
rough_2_files = glob.glob(path+"rough_2_*.txt")
rough_4_files = glob.glob(path+"rough_4_*.txt")
rough_6_files = glob.glob(path+"rough_6_*.txt")
rough_8_files = glob.glob(path+"rough_8_*.txt")
rough_10_files = glob.glob(path+"rough_10_*.txt")
rough_12_files = glob.glob(path+"rough_12_*.txt")

het_files = glob.glob(path+"het*.txt")

# %%
rough_4_files
# Out:
# ['rec_lattice_bounds/KPZ/sim_data_KPZ_long/rough_4_K1000000_M0.25_B10_G0.01_2020-08-20-15-16-56.txt',
#  'rec_lattice_bounds/KPZ/sim_data_KPZ_long/rough_4_K50000_M0.25_B3.5_G0.01_2020-08-20-15-34-32.txt',
#  'rec_lattice_bounds/KPZ/sim_data_KPZ_long/rough_4_K50000_M0.25_B3.5_G0.01_2020-08-20-15-34-26.txt',
#  'rec_lattice_bounds/KPZ/sim_data_KPZ_long/rough_4_K50000_M0.25_B2.5_G0.01_2020-08-20-15-34-05.txt',
#  'rec_lattice_bounds/KPZ/sim_data_KPZ_long/rough_4_K10000_M0.25_B2.5_G0.01_2020-08-20-15-43-50.txt',
#  'rec_lattice_bounds/KPZ/sim_data_KPZ_long/rough_4_K10000_M0.25_B2.5_G0.01_2020-08-20-15-43-44.txt',
#  'rec_lattice_bounds/KPZ/sim_data_KPZ_long/rough_4_K50000_M0.25_B2.5_G0.01_2020-08-20-15-34-11.txt',
#  'rec_lattice_bounds/KPZ/sim_data_KPZ_long/rough_4_K500000_M0.25_B6_G0.01_2020-08-20-15-26-49.txt',
#  'rec_lattice_bounds/KPZ/sim_data_KPZ_long/rough_4_K10000_M0.25_B3.5_G0.01_2020-08-20-15-45-12.txt',
# ...

# %%
K_var = [10000,50000, 500000,1000000]
K_str = ["K"+str(K)+"_" for K in K_var]


B_var = [0,2.5,3.5,6,10]
B_str = ["B"+str(B)+"_" for B in B_var]

# %%
n_files =20
rough_data_long=np.zeros((5,4,n_files,6,1000,3)) 
het_data_long=np.zeros((5,4,n_files,1000,2)) 
for Kn, Ki,K in zip(range(len(K_var)),K_var,K_str):
    for Bn,Bi,B in zip(range(len(B_var)),B_var,B_str):
        #print('hi')


        rough_sub_files_2=[]
        rough_sub_files_4=[]
        rough_sub_files_6=[]
        rough_sub_files_8=[]
        rough_sub_files_10=[]
        rough_sub_files_12=[]

        

        het_sub_files = []
        #for fr10,fr20,fr30,fr40,fr50,fr60,fr70 in zip(rough_10_files,rough_20_files,rough_30_files,rough_40_files,rough_50_files,rough_50_files,rough_50_files):
        #    print(fr10)
        #    if K in fr10 and B in fr10:
        #        rough_sub_files_10.append(fr10)

        for fr2,fr4,fr6,fr8,fr10,fr12,fh in zip(rough_2_files,rough_4_files,rough_6_files,rough_8_files,rough_10_files,rough_12_files,het_files):
            #print(fr10)

            if K in fr2 and B in fr2:
                rough_sub_files_2.append(fr2)
            if K in fr4 and B in fr4:
                rough_sub_files_4.append(fr4)
            if K in fr6 and B in fr6:
                 rough_sub_files_6.append(fr6)
            if K in fr8 and B in fr8:
                 rough_sub_files_8.append(fr8)
            if K in fr10 and B in fr10:
                rough_sub_files_10.append(fr10)
            if K in fr12 and B in fr12:
                rough_sub_files_12.append(fr12)
       

            if K in fh and B in fh:
                het_sub_files.append(fh)
#         for i, fr10,fr20,fr30,fr40,fr50,fr60,fr70,fr80,fr90,fr100,fr110,fr120,fr130,fr140,fr150,fr160,fr170,fr180 in zip(range(len(rough_sub_files_10)),rough_sub_files_10,rough_sub_files_20,rough_sub_files_30,rough_sub_files_40,
#                                                              rough_sub_files_50,rough_sub_files_60,rough_sub_files_70,rough_sub_files_80,
#                                                                                     rough_sub_files_90,rough_sub_files_100,rough_sub_files_110,
#                                                                                                        rough_sub_files_120,rough_sub_files_130,rough_sub_files_140,rough_sub_files_150,rough_sub_files_160,rough_sub_files_170,rough_sub_files_180):
#             rough_data[Bn,Kn,i,0]= np.loadtxt(fr10,delimiter =  ', ')
#             rough_data[Bn,Kn,i,1]= np.loadtxt(fr20,delimiter =  ', ')
#             rough_data[Bn,Kn,i,2]= np.loadtxt(fr30,delimiter =  ', ')
#             rough_data[Bn,Kn,i,3]= np.loadtxt(fr40,delimiter =  ', ')
#             rough_data[Bn,Kn,i,4]= np.loadtxt(fr50,delimiter =  ', ')
#             rough_data[Bn,Kn,i,5]= np.loadtxt(fr60,delimiter =  ', ')
#             rough_data[Bn,Kn,i,6]= np.loadtxt(fr70,delimiter =  ', ')
#             rough_data[Bn,Kn,i,7]= np.loadtxt(fr80,delimiter =  ', ')
#             rough_data[Bn,Kn,i,8]= np.loadtxt(fr90,delimiter =  ', ')
#             rough_data[Bn,Kn,i,9]= np.loadtxt(fr100,delimiter =  ', ')
#             rough_data[Bn,Kn,i,10]= np.loadtxt(fr110,delimiter =  ', ')
#             rough_data[Bn,Kn,i,11]= np.loadtxt(fr120,delimiter =  ', ')
#             rough_data[Bn,Kn,i,12]= np.loadtxt(fr130,delimiter =  ', ')
#             rough_data[Bn,Kn,i,13]= np.loadtxt(fr140,delimiter =  ', ')
#             rough_data[Bn,Kn,i,14]= np.loadtxt(fr150,delimiter =  ', ')
#             rough_data[Bn,Kn,i,15]= np.loadtxt(fr160,delimiter =  ', ')
#             rough_data[Bn,Kn,i,16]= np.loadtxt(fr170,delimiter =  ', ')
#             rough_data[Bn,Kn,i,17]= np.loadtxt(fr180,delimiter =  ', ')

            
                
        
        for i,fr2,fr4,fr6,fr8,fr10,fr12,fh in zip(range(n_files),rough_sub_files_2,rough_sub_files_4,rough_sub_files_6,rough_sub_files_8,rough_sub_files_10,rough_sub_files_12,het_sub_files):
         
            #arr = np.loadtxt(fr,delimiter =  ', ',skiprows=1)
            #rough_data[Bn,Kn,i,:,0]= np.concatenate((np.repeat(np.array([[0,10,20,30,40,50]]),1000,axis=0),
            #                             np.array([arr[:,-1]-8,arr[:,-1]-6,arr[:,-1]-4,arr[:,-1]-2,arr[:,-1]]).T),axis=1)
            #rough_data[Bn,Kn, i,:,1] = arr[:,1:-1]
            #print(i)
 

            rough_data_long[Bn,Kn,i,0]= np.loadtxt(fr2,delimiter =  ', ')
            rough_data_long[Bn,Kn,i,1]= np.loadtxt(fr4,delimiter =  ', ')
            rough_data_long[Bn,Kn,i,2]= np.loadtxt(fr6,delimiter =  ', ')
            rough_data_long[Bn,Kn,i,3]= np.loadtxt(fr8,delimiter =  ', ')
            rough_data_long[Bn,Kn,i,4]= np.loadtxt(fr10,delimiter =  ', ')
            rough_data_long[Bn,Kn,i,5]= np.loadtxt(fr12,delimiter =  ', ')


            het_data_long[Bn,Kn,i]= np.loadtxt(fh,delimiter =  ', ')

# %%
plt.plot((np.mean(rough_data_long[0,-1,:,:,:,2],axis=0).T/L_space  -np.min(rough_data_long[0,-1,:,i,0,2])/L_space)**.5)
# Out:
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in sqrt
#   """Entry point for launching an IPython kernel.
# ...

# %%
fig, ax= plt.subplots()

for i in range(len(L_space[:])):
    ax.scatter(L_space[i], (np.mean(rough_data_long[0,-1,:,i,250:1000,2])/L_space[i])**(.5),c='k')
    #print(L_space[i])
#plt.xscale('log')
#plt.yscale('log')


#plt.plot(L_space,L_space**.5)
def power_law(x, a,b):
    return a*(np.power((x), b))


xdata=L_space[:]
ydata = (np.mean((np.mean(rough_data_long[0,-1,:,:,250:1000,2] ,axis=2)/L_space[:]),axis=0)  )**.5


pars, cov = curve_fit(f=power_law, xdata=xdata, ydata=ydata, p0=[0,0 ], bounds=(-np.inf, np.inf))

ax.plot(xdata[:],(ydata[2]/xdata[2]**.5)*xdata[:]**.5,lw=4,linestyle='--',label='$L^{1/2}$')




ax.legend(fontsize=12)
for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(3)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)


#plt.plot( xdata, power_law(xdata,*pars))

ax.set_xlabel('L',fontsize=16)
ax.set_ylabel('$\omega (x,t)$',fontsize=16)

#ax.set_xscale('log')
ax.set_yscale('log')
#ax.plot(xdata,ydata)
ax.xaxis.set_tick_params(labelsize=16)
ax.yaxis.set_tick_params(labelsize=16)

# %%
L_space = np.array([2,4,6,8,10,12])
all_beta=np.zeros((len(B_var),len(K_var)))
for B in range(len(B_var)):
    for K in range(len(K_var[:])):
        xdata=L_space[:]
        ydata =  (np.mean((np.mean(rough_data_long[B,K,:,:,500:1000,2] ,axis=2)/L_space[:]),axis=0)  )**.5

        #xdata= np.mean(rough_data_big[B,K,:,-2,5:30,0],axis=0)
        #ydata = (np.mean(rough_data_big[B,K,:,-2,5:30,2],axis=0)/L_space[-2] - np.mean(rough_data_big[B,K,:,-2,0,2],axis=0)/L_space[-2])**.5
        pars, cov = curve_fit(f=power_law, xdata=xdata, ydata=ydata, p0=[0, 0], bounds=(-np.inf, np.inf))

        all_beta[B,K] = pars[1]

# %%
fig,ax=plt.subplots()
colors = pl.cm.viridis(np.linspace(0,1,5))
norm = matplotlib.colors.Normalize(vmin=0, vmax=8192)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
for i in range(5):
    ax.plot(all_beta[i].T,c=colors[i],label='B = ' +str(B_var[i]),lw=3,marker='o')

    
for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(3)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    ax.xaxis.set_tick_params(labelsize=16)
    ax.yaxis.set_tick_params(labelsize=16)
    
ax.set_xticks(range(4))
ax.set_xticklabels([r'$10^4$', r'$5 \times 10^4$',r'$5 \times 10^5$',r'$10^6$'])
ax.set_xlabel('K',fontsize=16)
ax.set_ylabel(r'$\beta$',fontsize=16)
ax.legend(bbox_to_anchor=(1,1),fontsize=14)

# %%
plt.plot(np.mean(rough_data_long[0,0,:,:,:,2],axis=0).T/ L_space[:] - np.mean(rough_data_long[0,0,:,:,0,2],axis=0)/ L_space[:])

# %%
np.mean(rough_data_long[0,0,:,:,0,2],axis=0)
# Out:
# array([ 24.4,  52.2, 108.1, 222. , 440.9])

# %%
(np.mean(rough_data_long[0,0,:,i,900:,1])/L_space[i] -np.mean(rough_data_long[0,0,:,i,0,1])/L_space[i] )**(.5)
# Out:
# 2.2676831169169116

# %%
path ="rec_lattice_bounds/KPZ/sim_data_KPZ_short/"
rough_64_files = glob.glob(path+"rough_64_*.txt")
rough_128_files = glob.glob(path+"rough_128_*.txt")
rough_256_files = glob.glob(path+"rough_256_*.txt")
rough_512_files = glob.glob(path+"rough_512_*.txt")
rough_1024_files = glob.glob(path+"rough_1024_*.txt")

het_files = glob.glob(path+"het*.txt")

# %%
K_var = [50000]
K_str = ["K"+str(K)+"_" for K in K_var]


B_var = [0,3.5,6]
B_str = ["B"+str(B)+"_" for B in B_var]

# %%
n_files =50
rough_data=np.zeros((3,1,n_files,5,1000,3)) 
het_data=np.zeros((3,1,n_files,1000,2)) 
for Kn, Ki,K in zip(range(len(K_var)),K_var,K_str):
    for Bn,Bi,B in zip(range(len(B_var)),B_var,B_str):
        #print('hi')


        rough_sub_files_64=[]
        rough_sub_files_128=[]
        rough_sub_files_256=[]
        rough_sub_files_512=[]
        rough_sub_files_1024=[]

        

        het_sub_files = []
        #for fr10,fr20,fr30,fr40,fr50,fr60,fr70 in zip(rough_10_files,rough_20_files,rough_30_files,rough_40_files,rough_50_files,rough_50_files,rough_50_files):
        #    print(fr10)
        #    if K in fr10 and B in fr10:
        #        rough_sub_files_10.append(fr10)

        for fr64,fr128,fr256,fr512,fr1024,fh in zip(rough_64_files,rough_128_files,rough_256_files,rough_512_files,rough_1024_files,het_files):
            #print(fr10)

            if K in fr64 and B in fr64:
                rough_sub_files_64.append(fr64)
            if K in fr128 and B in fr128:
                rough_sub_files_128.append(fr128)
            if K in fr256 and B in fr256:
                 rough_sub_files_256.append(fr256)
            if K in fr512 and B in fr512:
                 rough_sub_files_512.append(fr512)
            if K in fr1024 and B in fr1024:
                rough_sub_files_1024.append(fr1024)
       

            if K in fh and B in fh:
                het_sub_files.append(fh)
#         for i, fr10,fr20,fr30,fr40,fr50,fr60,fr70,fr80,fr90,fr100,fr110,fr120,fr130,fr140,fr150,fr160,fr170,fr180 in zip(range(len(rough_sub_files_10)),rough_sub_files_10,rough_sub_files_20,rough_sub_files_30,rough_sub_files_40,
#                                                              rough_sub_files_50,rough_sub_files_60,rough_sub_files_70,rough_sub_files_80,
#                                                                                     rough_sub_files_90,rough_sub_files_100,rough_sub_files_110,
#                                                                                                        rough_sub_files_120,rough_sub_files_130,rough_sub_files_140,rough_sub_files_150,rough_sub_files_160,rough_sub_files_170,rough_sub_files_180):
#             rough_data[Bn,Kn,i,0]= np.loadtxt(fr10,delimiter =  ', ')
#             rough_data[Bn,Kn,i,1]= np.loadtxt(fr20,delimiter =  ', ')
#             rough_data[Bn,Kn,i,2]= np.loadtxt(fr30,delimiter =  ', ')
#             rough_data[Bn,Kn,i,3]= np.loadtxt(fr40,delimiter =  ', ')
#             rough_data[Bn,Kn,i,4]= np.loadtxt(fr50,delimiter =  ', ')
#             rough_data[Bn,Kn,i,5]= np.loadtxt(fr60,delimiter =  ', ')
#             rough_data[Bn,Kn,i,6]= np.loadtxt(fr70,delimiter =  ', ')
#             rough_data[Bn,Kn,i,7]= np.loadtxt(fr80,delimiter =  ', ')
#             rough_data[Bn,Kn,i,8]= np.loadtxt(fr90,delimiter =  ', ')
#             rough_data[Bn,Kn,i,9]= np.loadtxt(fr100,delimiter =  ', ')
#             rough_data[Bn,Kn,i,10]= np.loadtxt(fr110,delimiter =  ', ')
#             rough_data[Bn,Kn,i,11]= np.loadtxt(fr120,delimiter =  ', ')
#             rough_data[Bn,Kn,i,12]= np.loadtxt(fr130,delimiter =  ', ')
#             rough_data[Bn,Kn,i,13]= np.loadtxt(fr140,delimiter =  ', ')
#             rough_data[Bn,Kn,i,14]= np.loadtxt(fr150,delimiter =  ', ')
#             rough_data[Bn,Kn,i,15]= np.loadtxt(fr160,delimiter =  ', ')
#             rough_data[Bn,Kn,i,16]= np.loadtxt(fr170,delimiter =  ', ')
#             rough_data[Bn,Kn,i,17]= np.loadtxt(fr180,delimiter =  ', ')

            
                
        
        for i,fr64,fr128,fr256,fr512,fr1024,fh in zip(range(n_files),rough_sub_files_64,rough_sub_files_128,rough_sub_files_256,rough_sub_files_512,rough_sub_files_1024,het_sub_files):
         
            #arr = np.loadtxt(fr,delimiter =  ', ',skiprows=1)
            #rough_data[Bn,Kn,i,:,0]= np.concatenate((np.repeat(np.array([[0,10,20,30,40,50]]),1000,axis=0),
            #                             np.array([arr[:,-1]-8,arr[:,-1]-6,arr[:,-1]-4,arr[:,-1]-2,arr[:,-1]]).T),axis=1)
            #rough_data[Bn,Kn, i,:,1] = arr[:,1:-1]
            #print(i)
 

            rough_data[Bn,Kn,i,0]= np.loadtxt(fr64,delimiter =  ', ')
            rough_data[Bn,Kn,i,1]= np.loadtxt(fr128,delimiter =  ', ')
            rough_data[Bn,Kn,i,2]= np.loadtxt(fr256,delimiter =  ', ')
            rough_data[Bn,Kn,i,3]= np.loadtxt(fr512,delimiter =  ', ')
            rough_data[Bn,Kn,i,4]= np.loadtxt(fr1024,delimiter =  ', ')


            het_data[Bn,Kn,i]= np.loadtxt(fh,delimiter =  ', ')

# %%
L_space = 2**np.array([6,7,8,9,10])

# %%
fig,axs=plt.subplots(1,2)

ax= axs[0]
colors = pl.cm.viridis(np.linspace(0,1,5))
norm = matplotlib.colors.Normalize(vmin=0, vmax=1024)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
for i in range(5):
    ax.scatter(np.mean(rough_data[0,0,:,i,:,0],axis=0),
            ((np.mean(rough_data[0,0,:,i,:,2],axis=0)/L_space[i])-(np.mean(rough_data[0,0,:,i,0,2],axis=0)/L_space[i]))**.5,
              s=4, label= "L = "+str( L_space[i]),color=colors[i])
    
    

def power_law(x, a, b):
    return a*(np.power((x), b))


xdata= np.mean(rough_data[0,0,:,-1,:10,0],axis=0)
ydata = (np.mean(rough_data[0,0,:,-1,:10,2],axis=0)/L_space[-1] - np.mean(rough_data[0,0,:,-1,0,2],axis=0)/L_space[-1])**.5
pars, cov = curve_fit(f=power_law, xdata=xdata, ydata=ydata, p0=[0, 0], bounds=(-np.inf, np.inf))


ax.plot(np.mean(rough_data[0,0,:,-1,:,0],axis=0),power_law(np.mean(rough_data[0,0,:,-1,:,0],axis=0),*pars),
        linestyle= "--", color = 'k' , label = '$L \propto t^{%f}$' % (pars[1]))
ax.legend()
ax.set_xlabel('Generations',fontsize=16)
ax.set_ylabel('$\omega (x,t)$',fontsize=16)

ax.set_xscale('log')
ax.set_yscale('log') 
for ax in axs:
    for axis in ['bottom','left']:
        ax.spines[axis].set_linewidth(3)
        ax.spines['right'].set_visible(False)
        ax.spines['top'].set_visible(False)

        ax.xaxis.set_tick_params(labelsize=16)
        ax.yaxis.set_tick_params(labelsize=16)

# %%
for i in range(len(L_space)):
    plt.scatter(L_space[i], np.mean(rough_data[2,0,:,i,950:,1])/L_space[i])

# %%
fig,ax=plt.subplots()


colors = pl.cm.viridis(np.linspace(0,1,5))
norm = matplotlib.colors.Normalize(vmin=0, vmax=1024)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
for i in range(5):
    ax.scatter(np.mean(rough_data[1,0,:,i,:,0],axis=0),
            ((np.mean(rough_data[1,0,:,i,:,2],axis=0)/L_space[i])-(np.mean(rough_data[1,0,:,i,0,2],axis=0)/L_space[i]))**.5,
              s=4, label= "L = "+str( L_space[i]),color=colors[i])
    
    
    
ax.scatter(np.mean(rough_data[1,0,:,i,:,0],axis=0),
        ((np.mean(rough_data[1,0,:,i,:,1],axis=0)/L_space[i]))**.5,
          s=4)

ax.set_xscale('log')
ax.set_yscale('log') 

def power_law(x,a, b):
    return a*(np.power((x), b))


xdata= np.mean(rough_data[1,0,:,-1,:10,0],axis=0)
ydata = (np.mean(rough_data[1,0,:,-1,:10,2],axis=0)/L_space[-1] - np.mean(rough_data[1,0,:,-1,0,2],axis=0)/L_space[-1])**.5
pars, cov = curve_fit(f=power_law, xdata=xdata, ydata=ydata, p0=[0,0], bounds=(-np.inf, np.inf))


ax.plot(np.mean(rough_data[1,0,:,-1,:,0],axis=0),power_law(np.mean(rough_data[1,0,:,-1,:,0],axis=0),*pars),
        linestyle= "--", color = 'k' , label = '$L \propto t^{%f}$' % (pars[1]))
ax.legend()

for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(3)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Generations',fontsize=16)
ax.set_ylabel('$\omega (x,t)$',fontsize=16)
# Out:
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in sqrt
#   # Remove the CWD from sys.path while we load stuff.
# Text(0,0.5,'$\\omega (x,t)$')

# %%
fig,ax=plt.subplots()


colors = pl.cm.viridis(np.linspace(0,1,5))
norm = matplotlib.colors.Normalize(vmin=0, vmax=1024)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
for i in range(5):
    ax.scatter(np.mean(rough_data[2,0,:,i,:,0],axis=0),
            ((np.mean(rough_data[2,0,:,i,:,2],axis=0)/L_space[i])-(np.mean(rough_data[2,0,:,i,0,2],axis=0)/L_space[i]))**.5,
              s=4, label= "L = "+str( L_space[i]),color=colors[i])
    

ax.set_xscale('log')
ax.set_yscale('log') 

def power_law(x,a, b):
    return a*(np.power((x), b))


xdata= np.mean(rough_data[2,0,:,-1,:16,0],axis=0)
ydata = (np.mean(rough_data[2,0,:,-1,:16,2],axis=0)/L_space[-1] - np.mean(rough_data[2,0,:,-1,0,2],axis=0)/L_space[-1])**.5
pars, cov = curve_fit(f=power_law, xdata=xdata, ydata=ydata, p0=[0,0], bounds=(-np.inf, np.inf))


ax.plot(np.mean(rough_data[2,0,:,-1,:,0],axis=0),power_law(np.mean(rough_data[2,0,:,-1,:,0],axis=0),*pars),
        linestyle= "--", color = 'k' , label = '$L \propto t^{%f}$' % (pars[1]))
ax.legend()

for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(3)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Generations',fontsize=16)
ax.set_ylabel('$\omega (x,t)$',fontsize=16)
# Out:
# Text(0,0.5,'$\\omega (x,t)$')

# %%
(np.mean(rough_data[2,0,:,-1,:10,2],axis=0)/L_space[-1] - np.mean(rough_data[2,0,:,-1,0,2],axis=0)/L_space[-1])**.5
# Out:
# array([0.        , 1.10082533, 1.27827398, 1.38326352, 1.4570478 ,
#        1.50785703, 1.54462905, 1.5985467 , 1.6251923 , 1.64107434])

# %%
# B = 0,K =50000 edge
fig,ax=plt.subplots()
#for i in range(4):
#    ax.plot(np.mean(rough_data[0,0,:,i,:60,0],axis=0),
#            ((np.mean(rough_data[0,0,:,i,:60,2],axis=0)/L_space[i])-(np.mean(rough_data[0,0,:60,i,0,2],axis=0)/L_space[i]))**.5)
    
    
    
#for i in range(4):
#    plt.plot(np.mean(rough_data[2,0,:,i,1:,0],axis=0),
#            ((np.mean(rough_data[2,0,:,i,1:,2],axis=0)/L_space[i])))
    
    
    

    #for i in range(4):
#    plt.plot(np.mean(rough_data[0,0,:,i,1:,0],axis=0),(np.mean(rough_data[0,0,:,i,1:,1],axis=0)/L_space[i])**(1/2))
    
    
#ax.plot(np.mean(rough_data[0,0,:,i,:,0],axis=0),.9*np.mean(rough_data[0,0,:,i,:,0],axis=0)**(.245))
ax.set_xscale('log')
ax.set_yscale('log')

def power_law(x, a, b):
    return a*(np.power((x), b))

xdata= np.mean(rough_data[0,0,:,-1,100:300,0],axis=0)
ydata = (np.mean(rough_data[0,0,:,-1,100:300,1],axis=0)/L_space[-1])**.5
pars, cov = curve_fit(f=power_law, xdata=xdata, ydata=ydata, p0=[0, 0], bounds=(-np.inf, np.inf))
plt.plot(xdata,power_law(xdata,*pars))
plt.plot(xdata,ydata)
#plt.plot(np.mean(rough_data[0,0,:,-1,:40,0],axis=0),(np.mean(rough_data[0,0,:,-1,:40,2],axis=0)/L_space[-1]-np.mean(rough_data[0,0,:,-1,0,2],axis=0)/L_space[-1])**.5)

#plt.plot((np.mean(rough_data[0,0,:,3,:,2],axis=0)/L_space[3])**(3/2))
#plt.plot((np.mean(rough_data[0,0,:,2,:,2],axis=0)/L_space[2])**(3/2))
#plt.plot((np.mean(rough_data[0,0,:,1,:,2],axis=0)/L_space[1])**(3/2))
#plt.plot((np.mean(rough_data[1,0,:,4,:,1],axis=0)/L_space[4])**(3/2))

# %%
plt.plot(np.fft.rfft((np.mean(rough_data[0,0,:,-1,100:300,1],axis=0)/L_space[-1])**.5))
#plt.xscale('log')
#plt.yscale('log')
# Out:
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
pars
# Out:
# array([4.19588417e-05, 1.35187728e+00])

# %%
plt.plot((np.mean(rough_data[1,0,:,-1,:200,0],axis=0)-500)**.5)
# Out:
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in sqrt
#   """Entry point for launching an IPython kernel.

# %%
for i in range(4):
    plt.plot(np.mean(rough_data[2,0,:,i,1:,0],axis=0),(np.mean(rough_data[2,0,:,i,1:,2],axis=0)/L_space[i])**(1/2))
    
    
#plt.plot(np.mean(rough_data[0,0,:,i,1:,0],axis=0),np.mean(rough_data[0,0,:,i,1:,0],axis=0)**(.24)+.6)
plt.xscale('log')
plt.yscale('log')

# %%
for i in range(4):
    plt.plot(np.mean(rough_data[1,0,:,i,1:,0],axis=0),(np.mean(rough_data[2,0,:,i,1:,2],axis=0)/L_space[i])**(1/2))
    
    
#plt.plot(np.mean(rough_data[0,0,:,i,1:,0],axis=0),np.mean(rough_data[0,0,:,i,1:,0],axis=0)**(.24)+.6)
plt.xscale('log')
plt.yscale('log')

# %%
z = 1.5
eta = .5



plt.plot(((np.mean(rough_data[2,0,:,6,:,1],axis=0)*L_space[6]-np.mean(rough_data[2,0,:,6,0,1],axis=0)*L_space[6])**.5)/L_space[6]**.5)

# plt.plot(np.mean(rough_data[3,0,:,4,:,0],axis=0),
#          (np.mean(rough_data[3,0,:,4,:,1],axis=0)**.5))

# plt.plot(np.mean(rough_data[3,0,:,3,:,0],axis=0),
#          (np.mean(rough_data[3,0,:,3,:,1],axis=0)**.5))

# plt.plot(np.mean(rough_data[3,0,:,2,:,0],axis=0),
#          (np.mean(rough_data[3,0,:,2,:,1],axis=0)**.5))



# plt.plot(np.mean(rough_data[3,0,:,2,:,0],axis=0),
#          (np.mean(rough_data[3,0,:,1,:,1],axis=0)**.5))

# %%
L_space[2]**.5
# Out:
# 8.0

# %%
import matplotlib.pylab as pl
from matplotlib import colors, cm
import matplotlib
from mpl_toolkits.axes_grid1 import make_axes_locatable

n = 18
c= np.arange(0,900,50)[:9]
colors = pl.cm.viridis(np.linspace(0,1,8))
norm = matplotlib.colors.Normalize(vmin=0, vmax=np.arange(0,900,50)[7])
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
fig,axs =plt.subplots(2,2,figsize=(9,6),sharex=True,sharey=True)

for j,b in enumerate([0,3]):
    for k in [0,1]:
        for i in range(8):
            axs[k,j].plot(het_data[b,k,0,:,0],np.mean(rough_data[b,k,:,i,:,1],axis=0)**.5,c=colors[i])
    

            axs[k,j].xaxis.set_tick_params(labelsize=14)
            axs[k,j].yaxis.set_tick_params(labelsize=14)
            axs[k,j].set_xlabel('Generations',fontsize=16)
            axs[k,j].set_ylabel('$\omega (x,t)$',fontsize=16)
            axs[k,j].set_title('K = '+ str(k) + "; " "B = " + str(b))



plt.colorbar(cmap, ticks=c)
cax.set_ylabel('L')
ax.text(0,40,r'B = 0, K = $5 \times 10^4$')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-157-d7aaad76f90b> in <module>()
#      15     for k in [0,1]:
#      16         for i in range(8):
# ---> 17             axs[k,j].plot(het_data[b,k,0,:,0],np.mean(rough_data[b,k,:,i,:,1],axis=0)**.5,c=colors[i])
#      18
#      19
#
# IndexError: index 1 is out of bounds for axis 1 with size 1

# %%
b
# Out:
# 3

# %%
plt.plot(np.mean(rough_data[3,1,:,7,50:100,1],axis=0)**(3/2))

# %%
import matplotlib.pylab as pl
from matplotlib import colors, cm
import matplotlib
from mpl_toolkits.axes_grid1 import make_axes_locatable

n = 18
c= np.arange(0,900,50)
colors = pl.cm.viridis(np.linspace(0,1,18))
norm = matplotlib.colors.Normalize(vmin=0, vmax=850)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
fig,axs =plt.subplots(2,2,figsize=(9,6),sharex=True,sharey=True)

for j,b in enumerate([0,3]):
    for k in [0,1]:
        for i in range(18):
            axs[k,j].plot(het_data[b,k,0,:,0],np.mean(rough_data[b,k,:,i,:,1],axis=0)**.5,c=colors[i])
    

            axs[k,j].xaxis.set_tick_params(labelsize=14)
            axs[k,j].yaxis.set_tick_params(labelsize=14)
            axs[k,j].set_xlabel('Generations',fontsize=16)
            axs[k,j].set_ylabel('$\omega (x,t)$',fontsize=16)
            axs[k,j].set_title('K = '+ str(k) + "; " "B = " + str(b))



plt.colorbar(cmap, ticks=c)
cax.set_ylabel('L')
ax.text(0,40,r'B = 0, K = $5 \times 10^4$')
# Out:
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in sqrt
# Text(0,40,'B = 0, K = $5 \\times 10^4$')

# %%
import matplotlib.pylab as pl
from matplotlib import colors, cm
import matplotlib
from mpl_toolkits.axes_grid1 import make_axes_locatable

n = 18
c= np.arange(0,900,50)[:9]
colors = pl.cm.viridis(np.linspace(0,1,n))
norm = matplotlib.colors.Normalize(vmin=0, vmax=np.arange(0,900,50)[8])
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
fig =plt.subplots(figsize=(6,9))
ax2 = plt.subplot(211)


divider = make_axes_locatable(ax2)
ax1 = divider.append_axes("top", size="30%", pad=0.08)
cax = divider.append_axes("right", size="5%", pad=0.08)

for i in range(8):
    ax2.plot(het_data[0,0,0,:,0],np.mean(rough_data[3,1,:,i,:,1],axis=0)**.5,c=colors[i])
    
    
ax1.plot(np.median(het_data[0,0,:,:,1],axis=0),lw=3)

ax1.set_xticklabels([])



ax1.yaxis.set_tick_params(labelsize=14)
ax2.xaxis.set_tick_params(labelsize=14)
ax2.yaxis.set_tick_params(labelsize=14)
ax2.set_xlabel('Generations',fontsize=16)
ax2.set_ylabel('$\omega (x,t)$',fontsize=16)
ax1.set_ylabel('$H$',fontsize=16)


#cb = plt.colorbar( i, ax=ax1, cax=cax )
    
plt.colorbar(cmap, ticks=c,cax=cax)
cax.set_ylabel('L')
ax2.text(0,40,r'B = 0, K = $5 \times 10^4$')
# Out:
# Text(0,40,'B = 0, K = $5 \\times 10^4$')

# %%
import matplotlib.pylab as pl
from matplotlib import colors, cm
import matplotlib
from mpl_toolkits.axes_grid1 import make_axes_locatable

n = 18
c= np.arange(10,190,10)
colors = pl.cm.viridis(np.linspace(0,1,n))
norm = matplotlib.colors.Normalize(vmin=0, vmax=180)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
fig =plt.subplots(figsize=(6,9))
ax2 = plt.subplot(211)


divider = make_axes_locatable(ax2)
ax1 = divider.append_axes("top", size="30%", pad=0.08)
cax = divider.append_axes("right", size="5%", pad=0.08)

for i in range(18):
    ax2.plot(het_data[1,1,0,:,0],np.median(rough_data[1,1,:,i,:,1],axis=0)**.5,c=colors[i])
    
    
ax1.plot(np.median(het_data[1,1,:50,:,1],axis=0),lw=3)

ax1.set_xticklabels([])



ax1.yaxis.set_tick_params(labelsize=14)
ax2.xaxis.set_tick_params(labelsize=14)
ax2.yaxis.set_tick_params(labelsize=14)
ax2.set_xlabel('Generations',fontsize=16)
ax2.set_ylabel('$\omega (x,t)$',fontsize=16)
ax1.set_ylabel('$H$',fontsize=16)


#cb = plt.colorbar( i, ax=ax1, cax=cax )
    
plt.colorbar(cmap, ticks=c,cax=cax)
cax.set_ylabel('L')
ax2.text(0,30,r'B = 2.5, K = $5 \times 10^4$')
# Out:
# Text(0,30,'B = 2.5, K = $5 \\times 10^4$')

# %%
import matplotlib.pylab as pl
from matplotlib import colors, cm
import matplotlib
from mpl_toolkits.axes_grid1 import make_axes_locatable

n = 18
c= np.arange(10,190,10)
colors = pl.cm.viridis(np.linspace(0,1,n))
norm = matplotlib.colors.Normalize(vmin=10, vmax=180)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
fig =plt.subplots(figsize=(6,9))
ax2 = plt.subplot(211)


divider = make_axes_locatable(ax2)
ax1 = divider.append_axes("top", size="30%", pad=0.08)
cax = divider.append_axes("right", size="5%", pad=0.08)

for i in range(18):
    ax2.plot(het_data[2,1,0,:,0],np.median(rough_data[2,1,:,i,:,1],axis=0)**.5,c=colors[i])
    
    
ax1.plot(np.median(het_data[1,1,:50,:,1],axis=0),lw=3)

ax1.set_xticklabels([])



ax1.yaxis.set_tick_params(labelsize=14)
ax2.xaxis.set_tick_params(labelsize=14)
ax2.yaxis.set_tick_params(labelsize=14)
ax2.set_xlabel('Generations',fontsize=16)
ax2.set_ylabel('$\omega (x,t)$',fontsize=16)
ax1.set_ylabel('$H$',fontsize=16)


#cb = plt.colorbar( i, ax=ax1, cax=cax )
    
plt.colorbar(cmap, ticks=c,cax=cax)
cax.set_ylabel('L')
ax2.text(0,15,r'B = 3.5, K = $5 \times 10^4$')
# Out:
# Text(0,15,'B = 3.5, K = $5 \\times 10^4$')

# %%
import matplotlib.pylab as pl
from matplotlib import colors, cm
import matplotlib
from mpl_toolkits.axes_grid1 import make_axes_locatable

n = 18
c= np.arange(10,190,10)
colors = pl.cm.viridis(np.linspace(0,1,n))
norm = matplotlib.colors.Normalize(vmin=10, vmax=180)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
fig =plt.subplots(figsize=(6,9))
ax2 = plt.subplot(211)


divider = make_axes_locatable(ax2)
ax1 = divider.append_axes("top", size="30%", pad=0.08)
cax = divider.append_axes("right", size="5%", pad=0.08)

for i in range(18):
    ax2.plot(het_data[3,1,0,:,0],np.median(rough_data[3,1,:,i,:,1],axis=0)**.5,c=colors[i])
    
    
ax1.plot(np.median(het_data[1,1,:50,:,1],axis=0),lw=3)

ax1.set_xticklabels([])



ax1.yaxis.set_tick_params(labelsize=14)
ax2.xaxis.set_tick_params(labelsize=14)
ax2.yaxis.set_tick_params(labelsize=14)
ax2.set_xlabel('Generations',fontsize=16)
ax2.set_ylabel('$\omega (x,t)$',fontsize=16)
ax1.set_ylabel('$H$',fontsize=16)


#cb = plt.colorbar( i, ax=ax1, cax=cax )
    
plt.colorbar(cmap, ticks=c,cax=cax)
cax.set_ylabel('L')
ax2.text(0,12,r'B = 6, K = $5 \times 10^4$')
# Out:
# Text(0,12,'B = 6, K = $5 \\times 10^4$')

# %%
plt.plot(het_data[3,1,0,:,0][200:],np.median(rough_data[3,1,:,-1,200:,1],axis=0),c=colors[i])

# %%
import matplotlib.pylab as pl
from matplotlib import colors, cm
import matplotlib
from mpl_toolkits.axes_grid1 import make_axes_locatable

n = 18
c= np.arange(10,190,10)
colors = pl.cm.viridis(np.linspace(0,1,n))
norm = matplotlib.colors.Normalize(vmin=10, vmax=180)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
fig =plt.subplots(figsize=(6,9))
ax2 = plt.subplot(211)


divider = make_axes_locatable(ax2)
ax1 = divider.append_axes("top", size="30%", pad=0.08)
cax = divider.append_axes("right", size="5%", pad=0.08)

for i in range(18):
    ax2.plot(het_data[0,0,0,:,0],np.median(rough_data[0,0,:,i,:,1],axis=0)**.5,c=colors[i])
    
    
ax1.plot(np.mean(het_data[0,0,:50,:,1],axis=0),lw=3)

ax1.set_xticklabels([])



ax1.yaxis.set_tick_params(labelsize=14)
ax2.xaxis.set_tick_params(labelsize=14)
ax2.yaxis.set_tick_params(labelsize=14)
ax2.set_xlabel('Generations',fontsize=16)
ax2.set_ylabel('$\omega (x,t)$',fontsize=16)
ax1.set_ylabel('$H$',fontsize=16)


#cb = plt.colorbar( i, ax=ax1, cax=cax )
    
plt.colorbar(cmap, ticks=c,cax=cax)
cax.set_ylabel('L')
ax2.text(0,70,r'B = 0, K = $10^4$')
# Out:
# Text(0,70,'B = 0, K = $10^4$')

# %%
fig,ax = plt.subplots()
for i in range(0,8):
    ax.plot(het_data[3,1,0,:,0],np.median(rough_data[3,1,:50,i,:,1],axis=0)**.5,c=colors[i])

# %%
fig,ax = plt.subplots()
n = 20
c= np.arange(10,190,10)
colors = pl.cm.viridis(np.linspace(0,1,n))
norm = matplotlib.colors.Normalize(vmin=100, vmax=180)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
j+=0
for i in range(13,18):
    ax.plot(het_data[3,1,0,:,0][:50],np.median(rough_data[3,1,:50,i,:50,1],axis=0)**(3/2),c=colors[i])

ax.set_ylabel('$\omega^3(x,t)$',fontsize=16)
ax.set_xlabel('Generations',fontsize=16)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)

plt.colorbar(cmap)

# %%
fig,ax = plt.subplots()
n = 20
c= np.arange(10,190,10)
colors = pl.cm.viridis(np.linspace(0,1,n))
norm = matplotlib.colors.Normalize(vmin=100, vmax=180)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
j+=0
for i in range(13,18):
    ax.plot(het_data[3,1,0,:,0][0:200],np.median(rough_data[3,1,:50,i,0:200,1],axis=0)**(3/2),c=colors[i])

ax.set_ylabel('$\omega^3(x,t)$',fontsize=16)
ax.set_xlabel('Generations',fontsize=16)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)

plt.colorbar(cmap)

# %%
fig,ax = plt.subplots()
n = 20
c= np.arange(10,190,10)
colors = pl.cm.viridis(np.linspace(0,1,n))
norm = matplotlib.colors.Normalize(vmin=100, vmax=180)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
j+=0
for i in range(13,18):
    ax.plot(het_data[3,1,0,:,0][10:45],np.median(rough_data[3,1,:50,i,10:45,1],axis=0)**(1/2),c=colors[i])

ax.set_ylabel('$\omega^3 (x,t)$',fontsize=16)
ax.set_xlabel('Generations',fontsize=16)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)

plt.colorbar(cmap)

# %%
plt.plot(het_data[3,1,0,:200,0],np.mean(het_data[3,1,:50,:200,1],axis=0))
plt.ylabel('H')
# Out:
# Text(0,0.5,'H')

# %%
fig,ax=plt.subplots()
ax.plot(np.arange(10,190,10)[:5],np.mean(np.median(rough_data[3,1,:50,:5,500:900,1],axis=0),axis=1),lw=4)
ax.set_xlabel('L',fontsize=16)
ax.set_ylabel('$\omega^2$',fontsize=16)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)

# %%
import matplotlib.pylab as pl
from matplotlib import colors, cm
import matplotlib
from mpl_toolkits.axes_grid1 import make_axes_locatable

n = 18
c= np.arange(10,190,10)
colors = pl.cm.viridis(np.linspace(0,1,n))
norm = matplotlib.colors.Normalize(vmin=10, vmax=180)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
fig =plt.subplots(figsize=(6,9))
ax2 = plt.subplot(211)





divider = make_axes_locatable(ax2)
ax1 = divider.append_axes("top", size="30%", pad=0.08)
cax = divider.append_axes("right", size="5%", pad=0.08)

for i in range(18):
    ax2.plot(het_data[1,0,0,:,0],np.median(rough_data[1,0,:,i,:,1],axis=0)**.5,c=colors[i])
    
    
ax1.plot(np.mean(het_data[1,0,:50,:,1],axis=0),lw=3)

ax1.set_xticklabels([])



ax1.yaxis.set_tick_params(labelsize=14)
ax2.xaxis.set_tick_params(labelsize=14)
ax2.yaxis.set_tick_params(labelsize=14)
ax2.set_xlabel('Generations',fontsize=16)
ax2.set_ylabel('$\omega (x,t)$',fontsize=16)
ax1.set_ylabel('$H$',fontsize=16)


#cb = plt.colorbar( i, ax=ax1, cax=cax )
    
plt.colorbar(cmap, ticks=c,cax=cax)
cax.set_ylabel('L')
ax2.text(0,35,r'B = 2.5, K = $10^4$')
# Out:
# Text(0,35,'B = 2.5, K = $10^4$')

# %%
import matplotlib.pylab as pl
from matplotlib import colors, cm
import matplotlib
from mpl_toolkits.axes_grid1 import make_axes_locatable

n = 18
c= np.arange(10,190,10)
colors = pl.cm.viridis(np.linspace(0,1,n))
norm = matplotlib.colors.Normalize(vmin=10, vmax=180)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
fig =plt.subplots(figsize=(6,9))
ax2 = plt.subplot(211)





divider = make_axes_locatable(ax2)
ax1 = divider.append_axes("top", size="30%", pad=0.08)
cax = divider.append_axes("right", size="5%", pad=0.08)

for i in range(18):
    ax2.plot(het_data[2,0,0,:,0],np.median(rough_data[2,0,:,i,:,1],axis=0)**.5,c=colors[i])
    
    
ax1.plot(np.mean(het_data[2,0,:50,:,1],axis=0),lw=3)

ax1.set_xticklabels([])



ax1.yaxis.set_tick_params(labelsize=14)
ax2.xaxis.set_tick_params(labelsize=14)
ax2.yaxis.set_tick_params(labelsize=14)
ax2.set_xlabel('Generations',fontsize=16)
ax2.set_ylabel('$\omega (x,t)$',fontsize=16)
ax1.set_ylabel('$H$',fontsize=16)


#cb = plt.colorbar( i, ax=ax1, cax=cax )
    
plt.colorbar(cmap, ticks=c,cax=cax)
cax.set_ylabel('L')
ax2.text(0,28,r'B = 3.5, K = $10^4$')
# Out:
# Text(0,28,'B = 3.5, K = $10^4$')

# %%
import matplotlib.pylab as pl
from matplotlib import colors, cm
import matplotlib
from mpl_toolkits.axes_grid1 import make_axes_locatable

n = 18
c= np.arange(10,190,10)
colors = pl.cm.viridis(np.linspace(0,1,n))
norm = matplotlib.colors.Normalize(vmin=10, vmax=180)
cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=matplotlib.cm.viridis)
cmap.set_array([])
fig =plt.subplots(figsize=(6,9))
ax2 = plt.subplot(211)





divider = make_axes_locatable(ax2)
ax1 = divider.append_axes("top", size="30%", pad=0.08)
cax = divider.append_axes("right", size="5%", pad=0.08)

for i in range(18):
    ax2.plot(het_data[3,0,0,:,0],np.median(rough_data[3,0,:,i,:,1],axis=0)**.5,c=colors[i])
    
    
ax1.plot(np.mean(het_data[3,0,:50,:,1],axis=0),lw=3)

ax1.set_xticklabels([])



ax1.yaxis.set_tick_params(labelsize=14)
ax2.xaxis.set_tick_params(labelsize=14)
ax2.yaxis.set_tick_params(labelsize=14)
ax2.set_xlabel('Generations',fontsize=16)
ax2.set_ylabel('$\omega (x,t)$',fontsize=16)
ax1.set_ylabel('$H$',fontsize=16)


#cb = plt.colorbar( i, ax=ax1, cax=cax )
    
plt.colorbar(cmap, ticks=c,cax=cax)
cax.set_ylabel('L')
ax2.text(0,21,r'B = 6, K = $10^4$')
# Out:
# Text(0,21,'B = 6, K = $10^4$')

# %%
fig,ax =plt.subplots()
ax.plot(np.mean(np.mean(rough_data[0,0,:50,:4,:,1],axis=0).T,axis=0))

# %%
fig,ax =plt.subplots()
ax.plot(np.mean(np.mean(rough_data[0,0,:50,-4:,200:300,1],axis=0).T,axis=0))

# %%
plt.plot(np.mean(rough_data[1,0,:50,:4,50:,1],axis=0).T)

# %%
plt.plot(np.arange(50)**(2/3))

# %%
fig,ax =plt.subplots()

for i in range(0,8):
    ax.plot(np.mean(rough_data[0,0,:50,i,:900,1],axis=0))

# %%
fig,ax =plt.subplots()

for i in range(17):
    ax.plot(np.mean(rough_data[2,0,:50,i,:1000,1],axis=0))

# %%
fig,ax =plt.subplots()

for i in range(17):
    ax.plot(np.mean(rough_data[3,0,:50,i,:1000,1],axis=0))

# %%
fig,ax =plt.subplots()

for i in range(4):
    ax.plot(np.mean(rough_data[2,0,:50,i,:,1],axis=0))

# %%
fig,ax =plt.subplots()

for i in range(4):
    ax.plot(np.mean(rough_data[3,0,:50,i,200:,1],axis=0))

# %%
fig,ax =plt.subplots()

for i in range(4,8):
    ax.plot(np.mean(rough_data[0,0,:50,i,200:,1],axis=0))

# %%
plt.plot(np.mean(rough_data[3,0,:-1,-1,200:,1],axis=0))
plt.plot(np.mean(rough_data[3,0,:-2,-1,200:,1],axis=0))
plt.plot(np.mean(rough_data[3,0,:-3,-1,200:,1],axis=0))
plt.plot(np.mean(rough_data[3,0,:-4,-1,200:,1],axis=0))

# %%
rough_data[3,0,:50,4,200:,1]
# Out:
# array([[0.461135, 0.462538, 0.461893, ..., 0.404289, 0.406414, 0.40645 ],
#        [0.471212, 0.47088 , 0.470003, ..., 0.458624, 0.460636, 0.460983],
#        [0.456095, 0.455784, 0.457002, ..., 0.425654, 0.425731, 0.427034],
#        ...,
#        [0.466551, 0.466671, 0.468485, ..., 0.425098, 0.424519, 0.424958],
#        [0.475169, 0.47446 , 0.474241, ..., 0.470774, 0.472054, 0.471666],
#        [0.479767, 0.47809 , 0.477474, ..., 0.477731, 0.477133, 0.477801]])

# %%
plt.plot(np.mean(np.mean(rough_data[3,0,:,:,50:,1],axis=0),axis=1))

# %%
plt.plot(np.mean(np.mean(rough_data[0,0,:,:,200:,1],axis=0),axis=1))

# %%
f = "rec_lattice_bounds/rough_180_K10000_M0.25_B0_G0.01_2020-08-02-17-11-26.txt"

# %%
plt.plot(np.loadtxt(f, delimiter = ", "))

# %%
plt.plot(np.mean(rough_data[1,0,:,0,:,1],axis=0))
plt.plot(np.mean(rough_data[1,0,:,1,:,1],axis=0))
plt.plot(np.mean(rough_data[1,0,:,2,:,1],axis=0))
plt.plot(np.mean(rough_data[1,0,:,3,:,1],axis=0))

# %%
plt.plot(np.mean(rough_data[0,0,:,0,:,1],axis=0))
plt.plot(np.mean(rough_data[0,0,:,1,:,1],axis=0))
plt.plot(np.mean(rough_data[0,0,:,2,:,1],axis=0))
plt.plot(np.mean(rough_data[0,0,:,3,:,1],axis=0))

# %%
#plt.plot(np.median(rough_data[0,0,np.all(rough_data[0,0,:,2,:,1]>=0,axis=1),2,:,1],axis=0))
#plt.plot(np.median(rough_data[0,0,np.all(rough_data[0,0,:,1,:,1]>=0,axis=1),1,:,1],axis=0))
plt.plot(np.mean(rough_data[0,0,np.all(rough_data[0,0,:,0,:,1]>=0,axis=1),0,600:,1],axis=0))

# %%
plt.plot(rough_data[0,0,60,0,:,1])

# %%
plt.plot(rough_data[0,0,20:30,:,1].T)

# %%
rough_data[0,0,np.all(rough_data[0,0,:,:,1]>0,axis=0),:,1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-5c314e051148> in <module>()
# ----> 1 rough_data[0,0,np.all(rough_data[0,0,:,:,1]>0,axis=0),:,1]
#
# IndexError: boolean index did not match indexed array along dimension 2; dimension is 1000 but corresponding boolean dimension is 4

# %%
len(np.all(rough_data[0,0,:,:,1]>0,axis=1))
# Out:
# 100

# %%
np.all(rough_data[0,0,:,:,1]>=0,axis=1)
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#        False,  True,  True,  True,  True,  True,  True, False,  True,
#        False,  True,  True,  True,  True,  True, False,  True, False,
#         True])

# %%
plt.plot(np.mean(rough_data[0,0,np.all(rough_data[0,0,:,:,1]>=0,axis=1),400:,1],axis=0))

# %%
rough_10_filesl = glob.glob("rec_lattice_bounds/sim_data_KPZ/rough_10*.txt")
rough_20_filesl = glob.glob("rec_lattice_bounds/sim_data_KPZ/rough_20*.txt")
rough_30_filesl = glob.glob("rec_lattice_bounds/sim_data_KPZ/rough_30*.txt")
rough_40_filesl = glob.glob("rec_lattice_bounds/sim_data_KPZ/rough_40*.txt")
rough_150_filesl = glob.glob("rec_lattice_bounds/sim_data_KPZ/rough_150*.txt")
rough_160_filesl = glob.glob("rec_lattice_bounds/sim_data_KPZ/rough_160*.txt")
rough_170_filesl = glob.glob("rec_lattice_bounds/sim_data_KPZ/rough_170*.txt")
rough_180_filesl = glob.glob("rec_lattice_bounds/sim_data_KPZ/rough_180*.txt")
het_filesl = glob.glob("rec_lattice_bounds/sim_data_KPZ/het*.txt")

# %%
K_var = [10000]
K_str = ["K"+str(K)+"_" for K in K_var]


B_var = [0, 3.5, 6]
B_str = ["B"+str(B)+"_" for B in B_var]

# %%
rough_data=np.zeros((3,1,10,8,1000,2)) 
het_data=np.zeros((3,1,10,1000,2)) 
for Kn, Ki,K in zip(range(len(K_var)),K_var,K_str):
    for Bn,Bi,B in zip(range(len(B_var)),B_var,B_str):

        rough_sub_files_150=[]
        rough_sub_files_160=[]
        rough_sub_files_170=[]
        rough_sub_files_180=[]
        rough_sub_files_10=[]
        rough_sub_files_20=[]
        rough_sub_files_30=[]
        rough_sub_files_40=[]
        het_sub_files = []

        for fr10,fr20,fr30,fr40,fr150,fr160,fr170,fr180,fh in zip(rough_10_filesl,rough_20_filesl,rough_30_filesl,rough_40_filesl,
                                                                  rough_150_filesl,rough_160_filesl,rough_170_filesl,rough_180_filesl,het_filesl):
            if K in fr150 and B in fr150:
                rough_sub_files_150.append(fr150)
            if K in fr160 and B in fr160:
                rough_sub_files_160.append(fr160)
            if K in fr170 and B in fr170:
                rough_sub_files_170.append(fr170)
            if K in fr180 and B in fr180:
                rough_sub_files_180.append(fr180)
            if K in fr10 and B in fr10:
                rough_sub_files_10.append(fr10)
            if K in fr20 and B in fr20:
                rough_sub_files_20.append(fr20)
            if K in fr30 and B in fr30:
                rough_sub_files_30.append(fr30)
            if K in fr40 and B in fr40:
                rough_sub_files_40.append(fr40)
            if K in fh and B in fh:
                het_sub_files.append(fh)
                
        
        for i,fr10,fr20,fr30,fr40,fr150,fr160,fr170,fr180,fh in zip(range(len(rough_10_filesl)),rough_sub_files_10,rough_sub_files_20,rough_sub_files_30,rough_sub_files_40,
                                                                   rough_sub_files_150,rough_sub_files_160,rough_sub_files_170,rough_sub_files_180, het_files):
         
            #arr = np.loadtxt(fr,delimiter =  ', ',skiprows=1)
            #rough_data[Bn,Kn,i,:,0]= np.concatenate((np.repeat(np.array([[0,10,20,30,40,50]]),1000,axis=0),
            #                             np.array([arr[:,-1]-8,arr[:,-1]-6,arr[:,-1]-4,arr[:,-1]-2,arr[:,-1]]).T),axis=1)
            #rough_data[Bn,Kn, i,:,1] = arr[:,1:-1]
            rough_data[Bn,Kn,i,4]= np.loadtxt(fr150,delimiter =  ', ')
            rough_data[Bn,Kn,i,5]= np.loadtxt(fr160,delimiter =  ', ')
            rough_data[Bn,Kn,i,6]= np.loadtxt(fr170,delimiter =  ', ')
            rough_data[Bn,Kn,i,7]= np.loadtxt(fr180,delimiter =  ', ')
            rough_data[Bn,Kn,i,0]= np.loadtxt(fr10,delimiter =  ', ')
            rough_data[Bn,Kn,i,1]= np.loadtxt(fr20,delimiter =  ', ')
            rough_data[Bn,Kn,i,2]= np.loadtxt(fr30,delimiter =  ', ')
            rough_data[Bn,Kn,i,3]= np.loadtxt(fr40,delimiter =  ', ')
            het_data[Bn,Kn,i]= np.loadtxt(fh,delimiter =  ', ')

# %%
rough_data[0,0,:,:,1]
# Out:
# array([[[100.,   5.],
#         [100.,  23.],
#         [100.,  52.],
#         [100.,  53.],
#         [100., 166.],
#         [100., 194.],
#         [100., 154.],
#         [100., 194.]],
#
#        [[100.,   8.],
#         [100.,  28.],
#         [100.,  32.],
#         [100.,  51.],
#         [100., 174.],
#         [100., 158.],
#         [100., 196.],
#         [100., 206.]],
#
#        [[100.,   8.],
#         [100.,   9.],
#         [100.,  23.],
#         [100.,  51.],
#         [100., 184.],
#         [100., 127.],
#         [100., 147.],
#         [100., 203.]],
#
#        [[100.,  29.],
#         [100.,  18.],
#         [100.,  27.],
#         [100.,  80.],
#         [100., 139.],
#         [100., 177.],
#         [100., 188.],
#         [100., 170.]],
#
#        [[100.,   4.],
#         [100.,  20.],
#         [100.,  37.],
#         [100.,  31.],
#         [100., 115.],
#         [100., 182.],
#         [100., 184.],
#         [100., 156.]],
#
#        [[100.,  18.],
# ...

# %%
plt.plot(np.mean(rough_data[2,0,:,0,:,1],axis=0))
plt.plot(np.mean(rough_data[2,0,:,1,:,1],axis=0))
plt.plot(np.mean(rough_data[2,0,:,2,:,1],axis=0))
plt.plot(np.mean(rough_data[2,0,:,3,:,1],axis=0))

# %%
plt.plot(np.mean(rough_data[0,0,:,4,:100,1],axis=0))
plt.plot(np.mean(rough_data[0,0,:,5,:100,1],axis=0))
plt.plot(np.mean(rough_data[0,0,:,6,:100,1],axis=0))
plt.plot(np.mean(rough_data[0,0,:,7,:100,1],axis=0))

# %%
plt.plot(np.mean(rough_data[0,0,:,0,:,1],axis=0))
plt.plot(np.mean(rough_data[0,0,:,1,:,1],axis=0))
plt.plot(np.mean(rough_data[0,0,:,2,:,1],axis=0))
plt.plot(np.mean(rough_data[0,0,:,3,:,1],axis=0))
#plt.plot(np.mean(rough_data[0,0,5:,5,:,1],axis=0))
#plt.plot(np.mean(rough_data[0,0,5:,6,:,1],axis=0))
#plt.plot(np.mean(rough_data[0,0,5:,7,:,1],axis=0))

# %%
plt.plot(rough_data[0,0,0,4,200:300,1])

# %%
plt.plot(np.mean(het_data[0,0,:,:,0],axis=0))

# %%
het_data[0,0,:,:,0]
# Out:
# array([[    0.,   100.,   200., ..., 99700., 99800., 99900.],
#        [    0.,   100.,   200., ..., 99700., 99800., 99900.],
#        [    0.,   100.,   200., ..., 99700., 99800., 99900.],
#        ...,
#        [    0.,   100.,   200., ..., 99700., 99800., 99900.],
#        [    0.,   100.,   200., ..., 99700., 99800., 99900.],
#        [    0.,   100.,   200., ..., 99700., 99800., 99900.]])

# %%
f= "rec_lattice_bounds/prof_K10000_M0.25_B0_G0.01_2020-08-07-17-07-34.txt"

# %%
plt.imshow(np.loadtxt(f,delimiter=", ")[:,2].reshape(900,120))

# %%
np.loadtxt(f,delimiter=", ")
# Out:
# array([[  0.,   0.,   1.,   0.],
#        [  0.,   1.,   1.,   0.],
#        [  0.,   2.,  10.,   0.],
#        ...,
#        [119., 897.,   0.,   0.],
#        [119., 898.,   0.,   0.],
#        [119., 899.,   0.,   0.]])

# %%
f
