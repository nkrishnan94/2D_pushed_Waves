# %%
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from profFuncs import*

# %%
f = glob.glob('long_range_jumps/prof*.txt')
f
# Out:
# ['long_range_jumps/prof_K500_M0.25_B5_G0.01_I250_J40_JN10_2020-12-15-10-00-48.txt',
#  'long_range_jumps/prof_K500_M0.25_B5_G0.01_I250_J30_JN5_2020-12-19-13-54-37.txt',
#  'long_range_jumps/prof_K500_M0.25_B5_G0.01_I250_J20_JN5_2020-12-19-13-50-10.txt',
#  'long_range_jumps/prof_K500_M0.25_B5_G0.01_I250_J15_JN20_2020-12-15-09-51-15.txt',
#  'long_range_jumps/prof_K500_M0.25_B5_G0.01_I250_J20_JN5_2020-12-19-14-16-24.txt',
#  'long_range_jumps/prof_K500_M0.25_B5_G0.01_I250_J40_JN10_2020-12-19-12-19-20.txt',
#  'long_range_jumps/prof_K500_M0.25_B5_G0.01_I250_J0_JN0_2020-12-19-14-18-36.txt',
#  'long_range_jumps/prof_K500_M0.25_B5_G0.01_I250_J20_JN5_2020-12-19-14-50-45.txt',
#  'long_range_jumps/prof_K500_M0.25_B5_G0.01_I250_J0_JN0_2020-12-15-09-54-18.txt',
#  'long_range_jumps/prof_K500_M0.25_B5_G0.01_I250_J40_JN10_2020-12-19-12-17-09.txt',
#  'long_range_jumps/prof_K500_M0.25_B5_G0.01_I250_J25_JN5_2020-12-19-14-12-38.txt',
#  'long_range_jumps/prof_K500_M0.25_B5_G0.01_I250_J0_JN0_2020-12-19-11-59-02.txt',
#  'long_range_jumps/prof_K500_M0.25_B0_G0.01_I250_J0_JN0_2020-12-15-10-13-28.txt',
#  'long_range_jumps/prof_K500_M0.25_B5_G0.01_I250_J40_JN10_2020-12-19-12-21-55.txt',
#  'long_range_jumps/prof_K500_M0.25_B0_G0.01_I250_J40_JN10_2020-12-15-10-06-18.txt']

# %%
# This dictionary defines the colormap
cdict = {'red':  ((0.0, 0.0, 0.0),   # no red at 0
                  (0.5, 1.0, 1.0),   # all channels set to 1.0 at 0.5 to create white
                  (1.0, 0.8, 0.8)),  # set to 0.8 so its not too bright at 1

        'green': ((0.0, 0.8, 0.8),   # set to 0.8 so its not too bright at 0
                  (0.5, 1.0, 1.0),   # all channels set to 1.0 at 0.5 to create white
                  (1.0, 0.0, 0.0)),  # no green at 1

        'blue':  ((0.0, 0.0, 0.0),   # no blue at 0
                  (0.5, 1.0, 1.0),   # all channels set to 1.0 at 0.5 to create white
                  (1.0, 0.0, 0.0))   # no blue at 1
       }

# Create the colormap using the dictionary
GnRd = colors.LinearSegmentedColormap('GnRd', cdict)
GnRd.set_bad('grey')

# %%
fig,ax=plt.subplots(figsize=(8,8))
freqArr_=arrToFreq(profFileToArray(f[7],500,500))

im = ax.imshow(freqArr_.T,cmap=GnRd
               #,norm=normalize
               ,vmin=0)
ax.set_xticks([])
ax.set_yticks([])
divider = make_axes_locatable(ax)
cax = divider.append_axes("bottom", size="5%", pad=0.05)
#cbar_ticks= [1,10,100,1000,10000]
cbar = fig.colorbar(im
                    #t,icks=cbar_ticks
                    ,orientation='horizontal',cax=cax)
#cbar.ax.set_xticklabels(cbar_ticks,fontsize=12) 
cbar.ax.tick_params(labelsize=20) 
cbar.ax.set_xlabel('Allele frequency',fontsize=20)

for axis in ['bottom','left','top','right']:
    ax.spines[axis].set_linewidth(1)

# %%
fig,ax=plt.subplots(figsize=(8,8))
freqArr_=arrToFreq(profFileToArray(f[1],500,500))

im = ax.imshow(freqArr_.T,cmap=GnRd
               #,norm=normalize
               ,vmin=0)
ax.set_xticks([])
ax.set_yticks([])
divider = make_axes_locatable(ax)
cax = divider.append_axes("bottom", size="5%", pad=0.05)
#cbar_ticks= [1,10,100,1000,10000]
cbar = fig.colorbar(im
                    #t,icks=cbar_ticks
                    ,orientation='horizontal',cax=cax)
#cbar.ax.set_xticklabels(cbar_ticks,fontsize=12) 
cbar.ax.tick_params(labelsize=20) 
cbar.ax.set_xlabel('Allele frequency',fontsize=20)

for axis in ['bottom','left','top','right']:
    ax.spines[axis].set_linewidth(1)

# %%
fig,ax=plt.subplots(figsize=(8,8))
freqArr_=arrToFreq(profFileToArray(f[2],500,500))

im = ax.imshow(freqArr_.T,cmap=GnRd
               #,norm=normalize
               ,vmin=0)
ax.set_xticks([])
ax.set_yticks([])
divider = make_axes_locatable(ax)
cax = divider.append_axes("bottom", size="5%", pad=0.05)
#cbar_ticks= [1,10,100,1000,10000]
cbar = fig.colorbar(im
                    #t,icks=cbar_ticks
                    ,orientation='horizontal',cax=cax)
#cbar.ax.set_xticklabels(cbar_ticks,fontsize=12) 
cbar.ax.tick_params(labelsize=20) 
cbar.ax.set_xlabel('Allele frequency',fontsize=20)

for axis in ['bottom','left','top','right']:
    ax.spines[axis].set_linewidth(1)

# %%
fig,ax=plt.subplots(figsize=(8,8))
freqArr_=arrToFreq(profFileToArray(f[4],500,500))

im = ax.imshow(freqArr_.T,cmap=GnRd
               #,norm=normalize
               ,vmin=0)
ax.set_xticks([])
ax.set_yticks([])
divider = make_axes_locatable(ax)
cax = divider.append_axes("bottom", size="5%", pad=0.05)
#cbar_ticks= [1,10,100,1000,10000]
cbar = fig.colorbar(im
                    #t,icks=cbar_ticks
                    ,orientation='horizontal',cax=cax)
#cbar.ax.set_xticklabels(cbar_ticks,fontsize=12) 
cbar.ax.tick_params(labelsize=20) 
cbar.ax.set_xlabel('Allele frequency',fontsize=20)

for axis in ['bottom','left','top','right']:
    ax.spines[axis].set_linewidth(1)

# %%
fig,ax=plt.subplots(figsize=(8,8))
freqArr_=arrToFreq(profFileToArray(f[3],500,500))

im = ax.imshow(freqArr_.T,cmap=GnRd
               #,norm=normalize
               ,vmin=0)
ax.set_xticks([])
ax.set_yticks([])
divider = make_axes_locatable(ax)
cax = divider.append_axes("bottom", size="5%", pad=0.05)
#cbar_ticks= [1,10,100,1000,10000]
cbar = fig.colorbar(im
                    #t,icks=cbar_ticks
                    ,orientation='horizontal',cax=cax)
#cbar.ax.set_xticklabels(cbar_ticks,fontsize=12) 
cbar.ax.tick_params(labelsize=20) 
cbar.ax.set_xlabel('Allele frequency',fontsize=20)

for axis in ['bottom','left','top','right']:
    ax.spines[axis].set_linewidth(1)

# %%
f[3]
# Out:
# 'long_range_jumps/prof_K500_M0.25_B5_G0.01_I250_J0_JN0_2020-12-15-09-54-18.txt'

# %%
f
# Out:
# ['long_range_jumps/prof_K500_M0.25_B5_G0.01_I250_J40_JN10_2020-12-15-10-00-48.txt',
#  'long_range_jumps/prof_K500_M0.25_B5_G0.01_I250_J15_JN20_2020-12-15-09-51-15.txt',
#  'long_range_jumps/prof_K500_M0.25_B5_G0.01_I250_J0_JN0_2020-12-15-09-54-18.txt',
#  'long_range_jumps/prof_K500_M0.25_B0_G0.01_I250_J0_JN0_2020-12-15-10-13-28.txt',
#  'long_range_jumps/prof_K500_M0.25_B0_G0.01_I250_J40_JN10_2020-12-15-10-06-18.txt']
