# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.zeros((10,10))

data[:,1] =1

# %%
fig,ax = plt.subplots(figsize=(9,9))

data = np.zeros((10,10))

data[:,:5] =100
im = ax.imshow(data,cmap = 'viridis',vmin= 0,vmax=100)
ax.set_xticks(np.arange(10)-.5)
ax.set_yticks(np.arange(10)-.5)
plt.grid(True,c='k')
ax.set_xticklabels([])
ax.set_yticklabels([])
[ax.text(i,-1,str(x)) for x,i in zip(np.arange(10),np.arange(10))]
[ax.text(-1,i,str(x)) for x,i in zip(np.arange(10),np.arange(10))]
#[ax.text(-1,i,str(y)) for y,i in zip(np.arange(5),np.arange(10))]
#[ax.text(-.1,i,str(y)) for y,i in zip(np.arange(5),[.1,.3,.5,.7,.9])]
ax.text(-.5,-1,'x =')
ax.text(-1.5,0,'y =')
cbar = plt.colorbar(im,ticks=[0,100])
cbar.ax.set_yticklabels(['0', 'N'])
# Out:
# [Text(1,0,'0'), Text(1,0,'N')]

# %%
fig,ax = plt.subplots(figsize=(9,9))

data = np.zeros((10,10))

data[:,:5] =100
im = ax.imshow(data,cmap = 'viridis',vmin= 0,vmax=100)
ax.set_xticks(np.arange(10)-.5)
ax.set_yticks(np.arange(10)-.5)
plt.grid(True,c='k')
ax.set_xticklabels([])
ax.set_yticklabels([])
[ax.text(i,-1,str(x)) for x,i in zip(np.arange(10),np.arange(10))]
[ax.text(-1,i,str(x)) for x,i in zip(np.arange(10),np.arange(10))]
#[ax.text(-1,i,str(y)) for y,i in zip(np.arange(5),np.arange(10))]
#[ax.text(-.1,i,str(y)) for y,i in zip(np.arange(5),[.1,.3,.5,.7,.9])]
ax.text(-.5,-1,'i =')
ax.text(-1.5,0,'j =')
cbar = plt.colorbar(im,ticks=[0,100])
cbar.ax.set_yticklabels(['0', 'N']) 

ax.arrow(4,5,.75,0,head_width=.2,color='k')
ax.arrow(4,5,-.75,0,head_width=.2,color='k')
ax.arrow(4,5,0,-.75,head_width=.2,color='k',clip_on = False)
ax.arrow(4,5,0,.75,head_width=.2,color='k',clip_on = False)
ax.text(5.1,5,'$-n(x,y)M/4$',bbox=dict(facecolor='white', alpha=0.5),fontsize=14)
ax.text(4.1,4,'$-n(x,y)M/4$',bbox=dict(facecolor='white', alpha=0.5),fontsize=14)
ax.text(.8,5,'$-n(x,y)M/4$',bbox=dict(facecolor='white', alpha=0.5),fontsize=14)
ax.text(4.1,6,'$-n(x,y)M/4$',bbox=dict(facecolor='white', alpha=0.5),fontsize=14)
# Out:
# Text(4.1,6,'$-n(x,y)M/4$')

# %%
fig,ax = plt.subplots(figsize=(9,9))

data = np.zeros((10,10))

data[:,:5] =100
im = ax.imshow(data,cmap = 'viridis',vmin= 0,vmax=100)
ax.set_xticks(np.arange(10)-.5)
ax.set_yticks(np.arange(10)-.5)
plt.grid(True,c='k')
ax.set_xticklabels([])
ax.set_yticklabels([])
[ax.text(i,-1,str(x)) for x,i in zip(np.arange(10),np.arange(10))]
[ax.text(-1,i,str(x)) for x,i in zip(np.arange(10),np.arange(10))]
#[ax.text(-1,i,str(y)) for y,i in zip(np.arange(5),np.arange(10))]
#[ax.text(-.1,i,str(y)) for y,i in zip(np.arange(5),[.1,.3,.5,.7,.9])]
ax.text(-.5,-1,'i =')
ax.text(-1.5,0,'j =')
cbar = plt.colorbar(im,ticks=[0,100])
cbar.ax.set_yticklabels(['0', 'N']) 


ax.arrow(5,5,-.75,0,head_width=.2,color='k')
ax.arrow(3,5,.75,0,head_width=.2,color='k')
ax.arrow(4,4,0,.75,head_width=.2,color='k',clip_on = False)
ax.arrow(4,6,0,-.75,head_width=.2,color='k',clip_on = False)
ax.text(5.1,5,'$n(x+1,y)M/4$',bbox=dict(facecolor='white', alpha=0.5),fontsize=14)
ax.text(4.1,4,'$n(x-1,j)M/4$',bbox=dict(facecolor='white', alpha=0.5),fontsize=14)
ax.text(.6,5,'$n(x,y-1)M/4$',bbox=dict(facecolor='white', alpha=0.5),fontsize=14)
ax.text(4.1,6,'$n(x,y+1)M/4$',bbox=dict(facecolor='white', alpha=0.5),fontsize=14)
# Out:
# Text(4.1,6,'$n(x,y+1)M/4$')

# %%
fig,ax = plt.subplots(figsize=(9,9))

data = np.zeros((10,10))

data[:,:5] =100
data[5,4]=75
data[5,5]=25
im = ax.imshow(data,cmap = 'viridis',vmin= 0,vmax=100)
ax.set_xticks(np.arange(10)-.5)
ax.set_yticks(np.arange(10)-.5)

cbar.ax.set_yticklabels(['0', 'N']) 

plt.grid(True,c='k')
ax.set_xticklabels([])
ax.set_yticklabels([])
[ax.text(i,-1,str(x)) for x,i in zip(np.arange(10),np.arange(10))]
[ax.text(-1,i,str(x)) for x,i in zip(np.arange(10),np.arange(10))]
#[ax.text(-1,i,str(y)) for y,i in zip(np.arange(5),np.arange(10))]
#[ax.text(-.1,i,str(y)) for y,i in zip(np.arange(5),[.1,.3,.5,.7,.9])]
ax.text(-.5,-1,'i =')
ax.text(-1.5,0,'j =')
cbar = plt.colorbar(im,ticks=[0,100])
cbar.ax.set_yticklabels(['0', 'N']) 

ax.text(3.5,6,"+ P($f_1$,$f_2$, n)",bbox=dict(facecolor='white', alpha=0.5),fontsize=14)


# ax.arrow(5,5,-.75,0,head_width=.2,color='k')
# ax.arrow(3,5,.75,0,head_width=.2,color='k')
# ax.arrow(4,4,0,.75,head_width=.2,color='k',clip_on = False)
# ax.arrow(4,6,0,-.75,head_width=.2,color='k',clip_on = False)
# ax.text(5.1,5,'$n_{i+1,j}M/4$',bbox=dict(facecolor='white', alpha=0.5),fontsize=14)
# ax.text(4.1,4,'$n_{i-1,j}M/4$',bbox=dict(facecolor='white', alpha=0.5),fontsize=14)
# ax.text(2,5,'$n_{i,j-1}M/4$',bbox=dict(facecolor='white', alpha=0.5),fontsize=14)
# ax.text(4.1,6,'$n_{i,j+1}M/4$',bbox=dict(facecolor='white', alpha=0.5),fontsize=14)
# Out:
# Text(3.5,6,'+ P($f_1$,$f_2$, n)')
